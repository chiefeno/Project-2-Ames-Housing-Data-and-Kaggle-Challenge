# %% [markdown]
# # Project 2:  Ames Housing Data and Kaggle Challenge

# %% [markdown]
# # Problem Statement

# %% [markdown]
# Given a dataset of houses and their features, we must find the best model to predict the sale price of these houses
# and understand which features of the houses influence the sale price the most. The goal is helping property owners in order to maximize their house values.

# %% [markdown]
# # Step 1 : Data Import and Cleaning

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
house_train_set = pd.read_csv('datasets/train.csv')

# %%
house_train_set
# Out:
#         Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0      109  533352170           60        RL           NaN     13517   Pave
# 1      544  531379050           60        RL          43.0     11492   Pave
# 2      153  535304180           20        RL          68.0      7922   Pave
# 3      318  916386060           60        RL          73.0      9802   Pave
# 4      255  906425045           50        RL          82.0     14235   Pave
# ...    ...        ...          ...       ...           ...       ...    ...
# 2046  1587  921126030           20        RL          79.0     11449   Pave
# 2047   785  905377130           30        RL           NaN     12342   Pave
# 2048   916  909253010           50        RL          57.0      7558   Pave
# 2049   639  535179160           20        RL          80.0     10400   Pave
# 2050    10  527162130           60        RL          60.0      7500   Pave
#
#      Alley Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0      NaN       IR1          Lvl  ...            0         0     NaN   NaN
# 1      NaN       IR1          Lvl  ...            0         0     NaN   NaN
# 2      NaN       Reg          Lvl  ...            0         0     NaN   NaN
# 3      NaN       Reg          Lvl  ...            0         0     NaN   NaN
# 4      NaN       IR1          Lvl  ...            0         0     NaN   NaN
# ...    ...       ...          ...  ...          ...       ...     ...   ...
# 2046   NaN       IR1          HLS  ...            0         0     NaN   NaN
# 2047   NaN       IR1          Lvl  ...            0         0     NaN   NaN
# 2048   NaN       Reg          Bnk  ...            0         0     NaN   NaN
# 2049   NaN       Reg          Lvl  ...            0         0     NaN   NaN
# 2050   NaN       Reg          Lvl  ...            0         0     NaN   NaN
#
#      Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 0             NaN        0       3    2010        WD      130500
# 1             NaN        0       4    2009        WD      220000
# 2             NaN        0       1    2010        WD      109000
# 3             NaN        0       4    2010        WD      174000
# 4             NaN        0       3    2010        WD      138500
# ...           ...      ...     ...     ...        ...        ...
# 2046          NaN        0       1    2008        WD      298751
# 2047          NaN        0       3    2009        WD       82500
# 2048          NaN        0       3    2009        WD      177000
# 2049          NaN        0      11    2009        WD      144000
# 2050          NaN        0       6    2010        WD      189000
#
# [2051 rows x 81 columns]

# %% [markdown]
# Let's rename the column in lowercase and using an underscore dash for separator

# %%
house_train_set.columns = house_train_set.columns.str.lower().str.replace(' ', '_')

# %% [markdown]
# We can check the shape of the dataframe; it's types and if it has any null values:

# %%
house_train_set.shape
# Out:
# (2051, 81)

# %%
pd.set_option("display.max_rows", 82 , "display.max_columns", 82)

# %%
house_train_set.dtypes
# Out:
# id                   int64
# pid                  int64
# ms_subclass          int64
# ms_zoning           object
# lot_frontage       float64
# lot_area             int64
# street              object
# alley               object
# lot_shape           object
# land_contour        object
# utilities           object
# lot_config          object
# land_slope          object
# neighborhood        object
# condition_1         object
# condition_2         object
# bldg_type           object
# house_style         object
# overall_qual         int64
# overall_cond         int64
# year_built           int64
# year_remod/add       int64
# roof_style          object
# roof_matl           object
# exterior_1st        object
# exterior_2nd        object
# mas_vnr_type        object
# mas_vnr_area       float64
# exter_qual          object
# exter_cond          object
# foundation          object
# bsmt_qual           object
# bsmt_cond           object
# bsmt_exposure       object
# bsmtfin_type_1      object
# bsmtfin_sf_1       float64
# bsmtfin_type_2      object
# bsmtfin_sf_2       float64
# bsmt_unf_sf        float64
# total_bsmt_sf      float64
# heating             object
# heating_qc          object
# central_air         object
# electrical          object
# 1st_flr_sf           int64
# 2nd_flr_sf           int64
# low_qual_fin_sf      int64
# gr_liv_area          int64
# bsmt_full_bath     float64
# bsmt_half_bath     float64
# full_bath            int64
# half_bath            int64
# bedroom_abvgr        int64
# kitchen_abvgr        int64
# kitchen_qual        object
# totrms_abvgrd        int64
# functional          object
# fireplaces           int64
# fireplace_qu        object
# garage_type         object
# garage_yr_blt      float64
# garage_finish       object
# garage_cars        float64
# garage_area        float64
# garage_qual         object
# garage_cond         object
# paved_drive         object
# wood_deck_sf         int64
# open_porch_sf        int64
# enclosed_porch       int64
# 3ssn_porch           int64
# screen_porch         int64
# pool_area            int64
# pool_qc             object
# fence               object
# misc_feature        object
# misc_val             int64
# mo_sold              int64
# yr_sold              int64
# sale_type           object
# saleprice            int64
# dtype: object

# %% [markdown]
# Let's look at the null values

# %%
house_train_set.isnull().sum()
# Out:
# id                    0
# pid                   0
# ms_subclass           0
# ms_zoning             0
# lot_frontage        330
# lot_area              0
# street                0
# alley              1911
# lot_shape             0
# land_contour          0
# utilities             0
# lot_config            0
# land_slope            0
# neighborhood          0
# condition_1           0
# condition_2           0
# bldg_type             0
# house_style           0
# overall_qual          0
# overall_cond          0
# year_built            0
# year_remod/add        0
# roof_style            0
# roof_matl             0
# exterior_1st          0
# exterior_2nd          0
# mas_vnr_type         22
# mas_vnr_area         22
# exter_qual            0
# exter_cond            0
# foundation            0
# bsmt_qual            55
# bsmt_cond            55
# bsmt_exposure        58
# bsmtfin_type_1       55
# bsmtfin_sf_1          1
# bsmtfin_type_2       56
# bsmtfin_sf_2          1
# bsmt_unf_sf           1
# total_bsmt_sf         1
# heating               0
# heating_qc            0
# central_air           0
# electrical            0
# 1st_flr_sf            0
# 2nd_flr_sf            0
# low_qual_fin_sf       0
# gr_liv_area           0
# bsmt_full_bath        2
# bsmt_half_bath        2
# full_bath             0
# half_bath             0
# bedroom_abvgr         0
# kitchen_abvgr         0
# kitchen_qual          0
# totrms_abvgrd         0
# functional            0
# fireplaces            0
# fireplace_qu       1000
# garage_type         113
# garage_yr_blt       114
# garage_finish       114
# garage_cars           1
# garage_area           1
# garage_qual         114
# garage_cond         114
# paved_drive           0
# wood_deck_sf          0
# open_porch_sf         0
# enclosed_porch        0
# 3ssn_porch            0
# screen_porch          0
# pool_area             0
# pool_qc            2042
# fence              1651
# misc_feature       1986
# misc_val              0
# mo_sold               0
# yr_sold               0
# sale_type             0
# saleprice             0
# dtype: int64

# %% [markdown]
# We have a lot of null values. Let's take care of the null values and data type for each columns going from the one with most null values to the one with least null values

# %% [markdown]
# The first column we look at is the 'pool_qc' column which represent the quality of the pool in the houses. Let's look at it's unique values

# %%
house_train_set.pool_qc.unique()
# Out:
# array([nan, 'Fa', 'Gd', 'Ex', 'TA'], dtype=object)

# %% [markdown]
# The null values here represent the houses with no pool. Since it's a categorical feature and not numerical, we can fill the nulls with 'No pool':

# %%
house_train_set[['pool_qc']] = house_train_set[['pool_qc']].fillna(value= 'No Pool')

# %% [markdown]
# The next column with the most null value is the 'misc_feature' column. Based on the data dictionary, it correspond to extra miscellaneous features that are not in other columns like an elevator, second garage or even a tennis court.
# The houses that have no extra features have a null in this column so I can replace the null with 'No extra features'

# %%
house_train_set[['misc_feature']] = house_train_set[['misc_feature']].fillna(value= 'No extra features')

# %% [markdown]
# I then look at the Alley column. It is the type of Alley access to the property. We can look at it's unique value:

# %%
house_train_set.alley.unique()
# Out:
# array([nan, 'Pave', 'Grvl'], dtype=object)

# %% [markdown]
# Some of the houses don't have an alley access and those houses are represented with the null values.
# Since it is a categorical feature, I can replace the null with 'No alley'. Also no problems concerning the data type

# %%
house_train_set[['alley']] = house_train_set[['alley']].fillna(value= 'No alley')

# %% [markdown]
# The fence column represent the fence quality of the house, let's look at the values in the column:

# %%
house_train_set.fence.unique()
# Out:
# array([nan, 'MnPrv', 'GdPrv', 'GdWo', 'MnWw'], dtype=object)

# %% [markdown]
# Once again, some houses have no fences thus the null values, let's fill those null values with 'No fence':

# %%
house_train_set[['fence']] = house_train_set[['fence']].fillna(value= 'No fence')

# %% [markdown]
# Based on the data dictionary, the fireplacequ column represent the fireplace quality of the houses. It is a categorical column. Let's look at it's unique values first:

# %%
house_train_set.fireplace_qu.unique()
# Out:
# array([nan, 'TA', 'Gd', 'Po', 'Ex', 'Fa'], dtype=object)

# %% [markdown]
# The null values here are the houses with no fireplace. Let's replace them with 'No fireplace'

# %%
house_train_set[['fireplace_qu']] = house_train_set[['fireplace_qu']].fillna(value= 'No Fireplace')

# %% [markdown]
# The next column is lot_frontage. It correspond to the linear feet of street connected to the property. Let's look at it's unique value first:

# %%
house_train_set.lot_frontage.unique()
# Out:
# array([ nan,  43.,  68.,  73.,  82., 137.,  35.,  70.,  21.,  64., 120.,
#         24.,  74.,  93.,  34.,  80.,  71.,  72., 109.,  40., 103., 100.,
#         92.,  65.,  75.,  60.,  30.,  79.,  41., 105., 107.,  81.,  36.,
#         63.,  32.,  94.,  44.,  50.,  48.,  67.,  88.,  83.,  53.,  58.,
#         57.,  52.,  87., 134.,  56.,  54., 140.,  78.,  85.,  90.,  96.,
#         62.,  49.,  59., 155.,  91.,  61.,  86., 128.,  77.,  42.,  89.,
#         51.,  69.,  55., 112.,  76., 125.,  98., 113., 102.,  22., 122.,
#         84., 119., 118.,  66.,  95., 108., 195., 106.,  39., 110., 130.,
#         97.,  45.,  37., 123.,  38., 129., 115.,  47., 114., 104.,  46.,
#        121., 124., 313., 141., 101.,  99., 160., 174.,  26., 144., 138.,
#        111.,  25.,  33., 200., 150., 117., 153., 116., 135.])

# %% [markdown]
# It is a numerical feature ! I assume that all houses are connected to a street. Let's calculate the mean of the non null value and compute it to the null value and change it's data type to float:

# %%
house_train_set['lot_frontage'].fillna(house_train_set['lot_frontage'].mean(), inplace=True)

# %%
house_train_set['lot_frontage'] = house_train_set['lot_frontage'].astype('float')

# %% [markdown]
# Let's look at the garage_type values

# %%
house_train_set.garage_type.unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'Basment', nan, '2Types', 'CarPort'],
#       dtype=object)

# %% [markdown]
# It is a categorical feature. Based on data dictionnary; the null values are the houses with no garage. Let's replace the nan with 'no garage'

# %%
house_train_set[['garage_type']] = house_train_set[['garage_type']].fillna(value= 'No Garage')

# %% [markdown]
# Let's look at the garage_yr_blt values

# %%
house_train_set.garage_yr_blt.unique()
# Out:
# array([1976., 1997., 1953., 2007., 1957., 1966., 2005., 1959., 1952.,
#        1969., 1971., 1900., 2000., 2004., 1916., 1963., 1977., 2009.,
#        1968., 1992., 1955., 1961., 1973., 1937.,   nan, 2003., 1981.,
#        1931., 1995., 1958., 1965., 2006., 1978., 1954., 1935., 1951.,
#        1996., 1999., 1920., 1930., 1924., 1960., 1949., 1986., 1956.,
#        1994., 1979., 1964., 2001., 1972., 1939., 1962., 1927., 1948.,
#        1967., 1993., 2010., 1915., 1987., 1970., 1988., 1982., 1941.,
#        1984., 1942., 1950., 2002., 1975., 2008., 1974., 1998., 1918.,
#        1938., 1985., 1923., 1980., 1991., 1946., 1940., 1990., 1896.,
#        1983., 1914., 1945., 1921., 1925., 1926., 1936., 1932., 1947.,
#        1929., 1910., 1917., 1922., 1934., 1989., 1928., 2207., 1933.,
#        1895., 1919.])

# %% [markdown]
# It is a numerical feature ! There are some null values but also outliers; houses built in 1896 or 1900 are possible but it would be useful to count those values. Also there is a 2207 value ? is it a typo ? otherwise it would be impossible. Let's count those values first.

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
house_train_set['garage_yr_blt'].value_counts(ascending=True)
# Out:
# 1918.0      1
# 1895.0      1
# 1896.0      1
# 1919.0      1
# 1917.0      1
# 1933.0      1
# 2207.0      1
# 1932.0      2
# 1934.0      2
# 1929.0      2
# 2010.0      2
# 1914.0      2
# 1947.0      3
# 1900.0      3
# 1931.0      3
# 1924.0      4
# 1915.0      4
# 1937.0      4
# 1927.0      4
# 1921.0      4
# 1923.0      5
# 1916.0      5
# 1910.0      5
# 1946.0      5
# 1928.0      6
# 1942.0      6
# 1982.0      6
# 1938.0      6
# 1925.0      6
# 1922.0      6
# 1936.0      7
# 1983.0      7
# 1935.0      7
# 1926.0      8
# 1945.0     10
# 1986.0     10
# 1949.0     10
# 1991.0     10
# 1941.0     10
# 1952.0     10
# 1984.0     11
# 1981.0     11
# 1951.0     12
# 1985.0     12
# 1989.0     12
# 1948.0     14
# 1988.0     14
# 1955.0     15
# 1987.0     16
# 1939.0     16
# 2009.0     17
# 1972.0     17
# 1969.0     18
# 1971.0     18
# 1974.0     19
# 1953.0     19
# 1961.0     20
# 1940.0     20
# 1957.0     20
# 1973.0     20
# 1930.0     20
# 1970.0     20
# 1960.0     21
# 1920.0     21
# 1990.0     21
# 1963.0     22
# 1980.0     22
# 1992.0     22
# 1959.0     23
# 1954.0     25
# 1979.0     25
# 1975.0     25
# 1962.0     25
# 1964.0     25
# 1994.0     25
# 1997.0     26
# 1967.0     26
# 1995.0     26
# 1965.0     27
# 2001.0     27
# 1966.0     29
# 1956.0     31
# 1996.0     31
# 1968.0     32
# 1950.0     32
# 1958.0     32
# 1978.0     33
# 1993.0     34
# 1976.0     35
# 1999.0     39
# 2002.0     40
# 2000.0     41
# 2008.0     44
# 1998.0     45
# 1977.0     46
# 2003.0     66
# 2004.0     72
# 2006.0     80
# 2007.0     84
# 2005.0    105
# Name: garage_yr_blt, dtype: int64

# %% [markdown]
# Considering there are only few instances of those really old houses, I think it's best to keep them. Let's look at the row where the garage_yr_blt is equal to 2207

# %%
house_train_set[house_train_set['garage_yr_blt'] == 2207]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1699  2261  916384070           20        RL          68.0      8298   Pave
#
#          alley lot_shape land_contour utilities lot_config land_slope  \
# 1699  No alley       IR1          HLS    AllPub     Inside        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 1699       Timber        Norm        Norm      1Fam      1Story             8
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 1699             5        2006            2007        Hip   CompShg
#
#      exterior_1st exterior_2nd mas_vnr_type  mas_vnr_area exter_qual  \
# 1699      VinylSd      VinylSd          NaN           NaN         Gd
#
#      exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 1699         TA      PConc        Gd        TA            Av            GLQ
#
#       bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 1699         583.0            Unf           0.0        963.0         1546.0
#
#      heating heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1699    GasA         Ex           Y      SBrkr        1564           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1699                0         1564             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1699          0              2              1           Ex              6
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1699        Typ           1           Gd      Attchd         2207.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 1699           RFn          2.0        502.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 1699           Y           132              0               0           0
#
#       screen_porch  pool_area  pool_qc     fence       misc_feature  misc_val  \
# 1699             0          0  No Pool  No fence  No extra features         0
#
#       mo_sold  yr_sold sale_type  saleprice
# 1699        9     2007       New     267300

# %% [markdown]
# We can see that the year_remod/add is 2007. This is probably when the garage was remodeled. Let's change this value to 2007 as it was probably a typo.

# %%
house_train_set['garage_yr_blt'] = house_train_set['garage_yr_blt'].replace([2207],2007)

# %% [markdown]
# Let's also fill the null values with 'No garage'

# %%
house_train_set[['garage_yr_blt']] = house_train_set[['garage_yr_blt']].fillna(value= 'No garage')

# %% [markdown]
# actually let's convert those to 0 to change the column type to float

# %%
house_train_set['garage_yr_blt'] = house_train_set['garage_yr_blt'].replace(['No garage'],0)

# %% [markdown]
# now let's convert this column to float:

# %%
house_train_set['garage_yr_blt'] = house_train_set['garage_yr_blt'].astype('float')

# %% [markdown]
# Let's look at the garage_finish values:

# %%
house_train_set.garage_finish.unique()
# Out:
# array(['RFn', 'Unf', 'Fin', nan], dtype=object)

# %% [markdown]
#  we can replace the null values to 'No garage' based on the info provided in the data dictionary:

# %%
house_train_set[['garage_finish']] = house_train_set[['garage_finish']].fillna(value= 'No Garage')

# %% [markdown]
# Let's look at the garage_qual values :

# %%
house_train_set[['garage_qual']] = house_train_set[['garage_qual']].fillna(value= 'No Garage')

# %% [markdown]
# There is also a garage_cond column which indicate the garage condition based on the data dictionary. I think it's redundant; it has the same null values that the garage_qual had and indicates the same thing. I decide to drop this column as it doesn't bring new information on the houses.

# %%
house_train_set.drop('garage_cond', axis=1, inplace=True)

# %% [markdown]
# Let's look at the bsmt_exposure values :

# %%
house_train_set.bsmt_exposure.unique()
# Out:
# array(['No', 'Gd', 'Av', nan, 'Mn'], dtype=object)

# %% [markdown]
# The No values represent houses that have a basement with no exposure. Here the null values represent houses with no basement. Let's replace the null values with 'No basement'. Let's also change the 'No' values to 'No exposure' for clarity

# %%
house_train_set['bsmt_exposure'] = house_train_set['bsmt_exposure'].replace(['No'],'No exposure')

# %%
house_train_set[['bsmt_exposure']] = house_train_set[['bsmt_exposure']].fillna(value= 'No basement')

# %% [markdown]
# the bsmtfin_type_2 column represent the quality of the basement second finished area (if present). It has 56 null values which are the houses with no basement. Let's fill the null values with 'No basement':

# %%
house_train_set[['bsmtfin_type_2']] = house_train_set[['bsmtfin_type_2']].fillna(value= 'No basement')

# %% [markdown]
# Let's look at bsmtfin_type_1 values :

# %%
house_train_set.bsmtfin_type_1.unique()
# Out:
# array(['GLQ', 'Unf', 'ALQ', 'Rec', nan, 'BLQ', 'LwQ'], dtype=object)

# %% [markdown]
# The null values are the houses with no basement; let's fill them with 'No basement':

# %%
house_train_set[['bsmtfin_type_1']] = house_train_set[['bsmtfin_type_1']].fillna(value= 'No basement')

# %% [markdown]
# Let's look at bsmt_qual values :

# %%
house_train_set.bsmt_qual.unique()
# Out:
# array(['TA', 'Gd', 'Fa', nan, 'Ex', 'Po'], dtype=object)

# %% [markdown]
# The null values in the bsmt_qual column represent the houses with no basement; let's fill them with 'No basement':

# %%
house_train_set[['bsmt_qual']] = house_train_set[['bsmt_qual']].fillna(value= 'No basement')

# %% [markdown]
# the bsmt_qual represent the height of a basement so let's rename it to bsmt_height

# %%
house_train_set.rename(columns={'bsmt_qual':'bsmt_height'}, inplace=True)

# %% [markdown]
# The bsmt_cond also have null values; let's observe it's unique values first:

# %%
house_train_set.bsmt_cond.unique()
# Out:
# array(['TA', 'Gd', nan, 'Fa', 'Po', 'Ex'], dtype=object)

# %% [markdown]
# The null values in this column are the houses with no basement again. Let's fill those null with 'No basement'

# %%
house_train_set[['bsmt_cond']] = house_train_set[['bsmt_cond']].fillna(value= 'No basement')

# %% [markdown]
# Let's look at the mas_vnr_type column values which contains 22 null:

# %%
house_train_set.mas_vnr_type.unique()
# Out:
# array(['BrkFace', 'None', nan, 'Stone', 'BrkCmn'], dtype=object)

# %% [markdown]
# I assume that the null values represent houses with no masonry veneer. There is already a value 'None' for these houses so I will fill the null values with 'None'

# %%
house_train_set[['mas_vnr_type']] = house_train_set[['mas_vnr_type']].fillna(value= 'None')

# %% [markdown]
# The mas_vnr_area column contains 22 null values. Let's look at it's unique values:

# %%
house_train_set.mas_vnr_area.unique()
# Out:
# array([2.890e+02, 1.320e+02, 0.000e+00, 8.200e+01, 1.800e+02, 1.920e+02,
#        2.320e+02, 4.560e+02, 1.480e+02,       nan, 3.000e+00, 3.360e+02,
#        4.800e+02, 3.200e+02, 1.040e+02, 3.350e+02, 4.000e+01, 1.100e+02,
#        1.060e+02, 5.130e+02, 1.840e+02, 5.220e+02, 1.430e+02, 3.480e+02,
#        1.170e+02, 5.100e+02, 1.450e+02, 9.600e+01, 6.680e+02, 5.000e+01,
#        2.280e+02, 6.500e+01, 3.610e+02, 7.480e+02, 1.970e+02, 5.720e+02,
#        1.280e+02, 1.200e+02, 2.540e+02, 8.600e+01, 3.000e+01, 5.400e+01,
#        2.460e+02, 3.970e+02, 2.960e+02, 1.440e+02, 9.020e+02, 2.610e+02,
#        2.600e+02, 2.750e+02, 5.700e+01, 1.050e+03, 3.590e+02, 1.080e+02,
#        6.620e+02, 5.000e+02, 2.100e+02, 1.650e+02, 2.080e+02, 3.600e+02,
#        1.600e+02, 6.400e+01, 2.240e+02, 2.060e+02, 1.160e+02, 6.510e+02,
#        5.040e+02, 2.520e+02, 3.370e+02, 8.400e+01, 3.090e+02, 4.660e+02,
#        6.000e+02, 1.890e+02, 3.680e+02, 1.980e+02, 1.400e+02, 9.220e+02,
#        1.600e+01, 1.800e+01, 9.000e+01, 4.250e+02, 2.450e+02, 2.340e+02,
#        7.660e+02, 2.190e+02, 1.820e+02, 1.360e+02, 5.760e+02, 2.700e+02,
#        1.500e+02, 2.560e+02, 1.760e+02, 4.790e+02, 6.470e+02, 1.150e+02,
#        2.210e+02, 2.720e+02, 7.140e+02, 9.500e+01, 1.700e+02, 1.720e+02,
#        2.000e+02, 2.050e+02, 1.620e+02, 2.400e+02, 1.000e+02, 4.120e+02,
#        5.640e+02, 7.400e+01, 4.680e+02, 2.980e+02, 1.490e+02, 6.040e+02,
#        1.050e+02, 4.280e+02, 3.320e+02, 4.520e+02, 1.640e+02, 6.600e+02,
#        3.650e+02, 1.115e+03, 1.570e+02, 5.250e+02, 4.100e+01, 3.240e+02,
#        2.160e+02, 2.360e+02, 1.740e+02, 3.400e+02, 2.740e+02, 3.900e+01,
#        2.220e+02, 5.200e+01, 1.380e+02, 5.710e+02, 2.270e+02, 2.300e+01,
#        2.390e+02, 4.220e+02, 9.400e+01, 4.720e+02, 6.400e+02, 6.300e+02,
#        3.760e+02, 9.450e+02, 5.620e+02, 1.110e+03, 5.540e+02, 2.030e+02,
#        3.020e+02, 7.200e+01, 1.670e+02, 1.780e+02, 2.680e+02, 2.400e+01,
#        1.250e+02, 2.420e+02, 5.680e+02, 1.830e+02, 4.200e+02, 1.350e+02,
#        1.790e+02, 1.690e+02, 5.410e+02, 9.700e+01, 1.680e+02, 2.800e+02,
#        5.800e+01, 3.270e+02, 2.120e+02, 2.880e+02, 8.500e+01, 3.600e+01,
#        2.830e+02, 6.000e+01, 1.710e+02, 5.600e+01, 2.530e+02, 2.020e+02,
#        9.900e+01, 1.130e+02, 3.500e+02, 3.510e+02, 5.100e+01, 2.380e+02,
#        2.300e+02, 7.300e+02, 6.320e+02, 3.830e+02, 3.120e+02, 1.400e+01,
#        1.460e+02, 2.640e+02, 4.400e+01, 1.340e+02, 3.040e+02, 8.160e+02,
#        1.860e+02, 4.420e+02, 2.550e+02, 3.620e+02, 1.120e+02, 6.800e+01,
#        1.260e+02, 1.420e+02, 2.150e+02, 2.350e+02, 1.300e+02, 4.200e+01,
#        2.200e+01, 1.220e+02, 2.330e+02, 3.100e+02, 1.000e+00, 3.000e+02,
#        5.180e+02, 3.380e+02, 5.670e+02, 9.700e+02, 1.240e+02, 8.000e+01,
#        2.040e+02, 1.960e+02, 6.030e+02, 1.140e+02, 8.860e+02, 6.900e+01,
#        4.920e+02, 5.060e+02, 3.660e+02, 2.590e+02, 2.440e+02, 1.990e+02,
#        2.940e+02, 2.840e+02, 8.900e+01, 2.760e+02, 2.900e+02, 3.850e+02,
#        2.990e+02, 3.780e+02, 2.580e+02, 6.160e+02, 9.200e+01, 9.800e+01,
#        2.500e+02, 3.910e+02, 4.300e+02, 1.900e+02, 3.330e+02, 1.770e+02,
#        7.960e+02, 7.600e+01, 4.000e+02, 8.940e+02, 6.700e+01, 3.820e+02,
#        6.200e+01, 4.430e+02, 3.200e+01, 2.480e+02, 1.010e+02, 4.730e+02,
#        2.180e+02, 2.260e+02, 4.500e+01, 1.020e+02, 2.140e+02, 1.090e+02,
#        3.640e+02, 8.700e+01, 7.050e+02, 2.370e+02, 3.530e+02, 1.129e+03,
#        1.031e+03, 3.050e+02, 2.000e+01, 8.800e+01, 4.060e+02, 2.950e+02,
#        1.230e+02, 1.940e+02, 3.560e+02, 1.095e+03, 1.540e+02, 6.740e+02,
#        2.910e+02, 1.660e+02, 3.800e+02, 5.730e+02, 1.630e+02, 2.430e+02,
#        4.510e+02, 1.270e+02, 5.190e+02, 2.200e+02, 5.020e+02, 2.570e+02,
#        1.610e+02, 3.280e+02, 4.910e+02, 5.790e+02, 4.240e+02, 3.870e+02,
#        1.600e+03, 4.180e+02, 1.047e+03, 6.520e+02, 4.600e+01, 3.220e+02,
#        3.100e+01, 2.510e+02, 3.550e+02, 1.880e+02, 3.060e+02, 3.790e+02,
#        5.280e+02, 2.780e+02, 5.260e+02, 2.700e+01, 6.730e+02, 4.020e+02,
#        2.800e+01, 2.790e+02, 7.340e+02, 4.500e+02, 6.500e+02, 3.800e+01,
#        3.700e+02, 7.500e+01, 3.150e+02, 4.100e+02, 4.340e+02, 6.300e+01,
#        7.240e+02, 4.700e+01, 7.600e+02, 3.440e+02, 1.580e+02, 7.380e+02,
#        8.600e+02, 6.920e+02, 4.320e+02, 1.190e+02, 3.750e+02, 5.140e+02,
#        2.920e+02, 3.180e+02, 1.180e+02, 3.810e+02, 7.720e+02, 7.000e+01,
#        3.940e+02, 1.224e+03, 5.300e+02, 1.530e+02, 3.720e+02, 6.600e+01,
#        1.560e+02, 4.700e+02, 2.810e+02, 3.230e+02, 2.620e+02, 2.250e+02,
#        7.100e+02, 4.230e+02, 7.310e+02, 4.360e+02, 3.420e+02, 1.210e+02,
#        6.640e+02, 4.260e+02])

# %% [markdown]
# First of all, since it's a numerical column, the 'No exposure' value should be replaced to 0. Also there were 22 null values in the mas_vnr_type and I concluded that there were houses with no masonry veneer. The 22 null in this column represent those houses and can be filled with 0:

# %%
house_train_set[['mas_vnr_area']] = house_train_set[['mas_vnr_area']].fillna(value=0)

# %% [markdown]
# Let's change the mas_vnr_area to a float type:

# %%
house_train_set['mas_vnr_area'] = house_train_set['mas_vnr_area'].astype('float')

# %% [markdown]
# Alright; I took care of all the columns containing a substansial number of null values; let's observe what we have left:

# %%
house_train_set.isnull().sum()
# Out:
# id                 0
# pid                0
# ms_subclass        0
# ms_zoning          0
# lot_frontage       0
# lot_area           0
# street             0
# alley              0
# lot_shape          0
# land_contour       0
# utilities          0
# lot_config         0
# land_slope         0
# neighborhood       0
# condition_1        0
# condition_2        0
# bldg_type          0
# house_style        0
# overall_qual       0
# overall_cond       0
# year_built         0
# year_remod/add     0
# roof_style         0
# roof_matl          0
# exterior_1st       0
# exterior_2nd       0
# mas_vnr_type       0
# mas_vnr_area       0
# exter_qual         0
# exter_cond         0
# foundation         0
# bsmt_height        0
# bsmt_cond          0
# bsmt_exposure      0
# bsmtfin_type_1     0
# bsmtfin_sf_1       1
# bsmtfin_type_2     0
# bsmtfin_sf_2       1
# bsmt_unf_sf        1
# total_bsmt_sf      1
# heating            0
# heating_qc         0
# central_air        0
# electrical         0
# 1st_flr_sf         0
# 2nd_flr_sf         0
# low_qual_fin_sf    0
# gr_liv_area        0
# bsmt_full_bath     2
# bsmt_half_bath     2
# full_bath          0
# half_bath          0
# bedroom_abvgr      0
# kitchen_abvgr      0
# kitchen_qual       0
# totrms_abvgrd      0
# functional         0
# fireplaces         0
# fireplace_qu       0
# garage_type        0
# garage_yr_blt      0
# garage_finish      0
# garage_cars        1
# garage_area        1
# garage_qual        0
# paved_drive        0
# wood_deck_sf       0
# open_porch_sf      0
# enclosed_porch     0
# 3ssn_porch         0
# screen_porch       0
# pool_area          0
# pool_qc            0
# fence              0
# misc_feature       0
# misc_val           0
# mo_sold            0
# yr_sold            0
# sale_type          0
# saleprice          0
# dtype: int64

# %% [markdown]
# Since we only have singular instances of null values in few columns, I feel confident droping the remaining nulls without losing the integrity of the data

# %%
house_train_set.dropna(inplace=True)

# %% [markdown]
# Let's make sure all the data types are correct before we can make any calculations. To do that I will use the head method and look to see if there are number and confirm it with the dtype serie:

# %%
house_train_set.head(2)
# Out:
#     id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0  109  533352170           60        RL       69.0552     13517   Pave
# 1  544  531379050           60        RL       43.0000     11492   Pave
#
#       alley lot_shape land_contour utilities lot_config land_slope  \
# 0  No alley       IR1          Lvl    AllPub    CulDSac        Gtl
# 1  No alley       IR1          Lvl    AllPub    CulDSac        Gtl
#
#   neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 0       Sawyer        RRAe        Norm      1Fam      2Story             6
# 1      SawyerW        Norm        Norm      1Fam      2Story             7
#
#    overall_cond  year_built  year_remod/add roof_style roof_matl exterior_1st  \
# 0             8        1976            2005      Gable   CompShg      HdBoard
# 1             5        1996            1997      Gable   CompShg      VinylSd
#
#   exterior_2nd mas_vnr_type  mas_vnr_area exter_qual exter_cond foundation  \
# 0      Plywood      BrkFace         289.0         Gd         TA     CBlock
# 1      VinylSd      BrkFace         132.0         Gd         TA      PConc
#
#   bsmt_height bsmt_cond bsmt_exposure bsmtfin_type_1  bsmtfin_sf_1  \
# 0          TA        TA   No exposure            GLQ         533.0
# 1          Gd        TA   No exposure            GLQ         637.0
#
#   bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf heating heating_qc  \
# 0            Unf           0.0        192.0          725.0    GasA         Ex
# 1            Unf           0.0        276.0          913.0    GasA         Ex
#
#   central_air electrical  1st_flr_sf  2nd_flr_sf  low_qual_fin_sf  \
# 0           Y      SBrkr         725         754                0
# 1           Y      SBrkr         913        1209                0
#
#    gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  half_bath  \
# 0         1479             0.0             0.0          2          1
# 1         2122             1.0             0.0          2          1
#
#    bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd functional  \
# 0              3              1           Gd              6        Typ
# 1              4              1           Gd              8        Typ
#
#    fireplaces  fireplace_qu garage_type  garage_yr_blt garage_finish  \
# 0           0  No Fireplace      Attchd         1976.0           RFn
# 1           1            TA      Attchd         1997.0           RFn
#
#    garage_cars  garage_area garage_qual paved_drive  wood_deck_sf  \
# 0          2.0        475.0          TA           Y             0
# 1          2.0        559.0          TA           Y             0
#
#    open_porch_sf  enclosed_porch  3ssn_porch  screen_porch  pool_area  \
# 0             44               0           0             0          0
# 1             74               0           0             0          0
#
#    pool_qc     fence       misc_feature  misc_val  mo_sold  yr_sold sale_type  \
# 0  No Pool  No fence  No extra features         0        3     2010       WD
# 1  No Pool  No fence  No extra features         0        4     2009       WD
#
#    saleprice
# 0     130500
# 1     220000

# %%
house_train_set.dtypes
# Out:
# id                   int64
# pid                  int64
# ms_subclass          int64
# ms_zoning           object
# lot_frontage       float64
# lot_area             int64
# street              object
# alley               object
# lot_shape           object
# land_contour        object
# utilities           object
# lot_config          object
# land_slope          object
# neighborhood        object
# condition_1         object
# condition_2         object
# bldg_type           object
# house_style         object
# overall_qual         int64
# overall_cond         int64
# year_built           int64
# year_remod/add       int64
# roof_style          object
# roof_matl           object
# exterior_1st        object
# exterior_2nd        object
# mas_vnr_type        object
# mas_vnr_area       float64
# exter_qual          object
# exter_cond          object
# foundation          object
# bsmt_height         object
# bsmt_cond           object
# bsmt_exposure       object
# bsmtfin_type_1      object
# bsmtfin_sf_1       float64
# bsmtfin_type_2      object
# bsmtfin_sf_2       float64
# bsmt_unf_sf        float64
# total_bsmt_sf      float64
# heating             object
# heating_qc          object
# central_air         object
# electrical          object
# 1st_flr_sf           int64
# 2nd_flr_sf           int64
# low_qual_fin_sf      int64
# gr_liv_area          int64
# bsmt_full_bath     float64
# bsmt_half_bath     float64
# full_bath            int64
# half_bath            int64
# bedroom_abvgr        int64
# kitchen_abvgr        int64
# kitchen_qual        object
# totrms_abvgrd        int64
# functional          object
# fireplaces           int64
# fireplace_qu        object
# garage_type         object
# garage_yr_blt      float64
# garage_finish       object
# garage_cars        float64
# garage_area        float64
# garage_qual         object
# paved_drive         object
# wood_deck_sf         int64
# open_porch_sf        int64
# enclosed_porch       int64
# 3ssn_porch           int64
# screen_porch         int64
# pool_area            int64
# pool_qc             object
# fence               object
# misc_feature        object
# misc_val             int64
# mo_sold              int64
# yr_sold              int64
# sale_type           object
# saleprice            int64
# dtype: object

# %% [markdown]
# All the data types are correct; let's save this dataframe to a csv file calling it 'house_train_set'

# %%
house_train_set.to_csv('datasets/house_train_set.csv')

# %% [markdown]
# Let's import the test data set :

# %%
house_test_data = pd.read_csv('datasets/test.csv')

# %%
house_test_data.head(5)
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        Norm        Norm    2fmCon      2Story             6             8
# 1        Norm        Norm    Duplex      1Story             5             4
# 2        Norm        Norm      1Fam      2Story             7             5
# 3        Norm        Norm      1Fam      1Story             5             6
# 4        Norm        Norm      1Fam      1Story             6             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1910            1950      Gable   CompShg      AsbShng      AsbShng
# 1        1977            1977      Gable   CompShg      Plywood      Plywood
# 2        2006            2006      Gable   CompShg      VinylSd      VinylSd
# 3        1923            2006      Gable   CompShg      Wd Sdng      Wd Sdng
# 4        1963            1963      Gable   CompShg      Plywood      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0         None           0.0         TA         Fa      Stone        Fa
# 1         None           0.0         TA         TA     CBlock        Gd
# 2         None           0.0         Gd         TA      PConc        Gd
# 3         None           0.0         Gd         TA     CBlock        TA
# 4      BrkFace         247.0         TA         TA     CBlock        Gd
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            Unf             0            Unf
# 1        TA            No            Unf             0            Unf
# 2        Gd            Av            GLQ           554            Unf
# 3        TA            No            Unf             0            Unf
# 4        TA            No            BLQ           609            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0             0         1020           1020    GasA         Gd           N
# 1             0         1967           1967    GasA         TA           Y
# 2             0          100            654    GasA         Ex           Y
# 3             0          968            968    GasA         TA           Y
# 4             0          785           1394    GasA         Gd           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      FuseP         908        1020                0         1928
# 1      SBrkr        1967           0                0         1967
# 2      SBrkr         664         832                0         1496
# 3      SBrkr         968           0                0          968
# 4      SBrkr        1394           0                0         1394
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0               0               0          2          0              4
# 1               0               0          2          0              6
# 2               1               0          2          1              3
# 3               0               0          1          0              2
# 4               1               0          1          1              3
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              2           Fa              9        Typ           0
# 1              2           TA             10        Typ           0
# 2              1           Gd              7        Typ           1
# 3              1           TA              5        Typ           0
# 4              1           TA              6        Typ           2
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Detchd         1910.0           Unf            1
# 1          NaN      Attchd         1977.0           Fin            2
# 2           Gd      Attchd         2006.0           RFn            2
# 3          NaN      Detchd         1935.0           Unf            2
# 4           Gd      Attchd         1963.0           RFn            2
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0          440          Po          Po           Y             0
# 1          580          TA          TA           Y           170
# 2          426          TA          TA           Y           100
# 3          480          Fa          TA           N             0
# 4          514          TA          TA           Y             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             60             112           0             0          0     NaN
# 1              0               0           0             0          0     NaN
# 2             24               0           0             0          0     NaN
# 3              0             184           0             0          0     NaN
# 4             76               0           0           185          0     NaN
#
#   Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type
# 0   NaN          NaN         0        4     2006       WD
# 1   NaN          NaN         0        8     2006       WD
# 2   NaN          NaN         0        9     2006       New
# 3   NaN          NaN         0        7     2007       WD
# 4   NaN          NaN         0        7     2009       WD

# %% [markdown]
# The house test data has the same number of features minus the sale price which we are trying to predict. Let's  rename the column as we did on the house_train_set and check the null values:

# %%
house_test_data.columns = house_test_data.columns.str.lower().str.replace(' ', '_')

# %%
pd.set_option("display.max_rows", 82 , "display.max_columns", 82)

# %%
house_test_data.isnull().sum()
# Out:
# id                   0
# pid                  0
# ms_subclass          0
# ms_zoning            0
# lot_frontage       160
# lot_area             0
# street               0
# alley              820
# lot_shape            0
# land_contour         0
# utilities            0
# lot_config           0
# land_slope           0
# neighborhood         0
# condition_1          0
# condition_2          0
# bldg_type            0
# house_style          0
# overall_qual         0
# overall_cond         0
# year_built           0
# year_remod/add       0
# roof_style           0
# roof_matl            0
# exterior_1st         0
# exterior_2nd         0
# mas_vnr_type         1
# mas_vnr_area         1
# exter_qual           0
# exter_cond           0
# foundation           0
# bsmt_qual           25
# bsmt_cond           25
# bsmt_exposure       25
# bsmtfin_type_1      25
# bsmtfin_sf_1         0
# bsmtfin_type_2      25
# bsmtfin_sf_2         0
# bsmt_unf_sf          0
# total_bsmt_sf        0
# heating              0
# heating_qc           0
# central_air          0
# electrical           1
# 1st_flr_sf           0
# 2nd_flr_sf           0
# low_qual_fin_sf      0
# gr_liv_area          0
# bsmt_full_bath       0
# bsmt_half_bath       0
# full_bath            0
# half_bath            0
# bedroom_abvgr        0
# kitchen_abvgr        0
# kitchen_qual         0
# totrms_abvgrd        0
# functional           0
# fireplaces           0
# fireplace_qu       422
# garage_type         44
# garage_yr_blt       45
# garage_finish       45
# garage_cars          0
# garage_area          0
# garage_qual         45
# garage_cond         45
# paved_drive          0
# wood_deck_sf         0
# open_porch_sf        0
# enclosed_porch       0
# 3ssn_porch           0
# screen_porch         0
# pool_area            0
# pool_qc            874
# fence              706
# misc_feature       837
# misc_val             0
# mo_sold              0
# yr_sold              0
# sale_type            0
# dtype: int64

# %% [markdown]
# The null values are present in the same columns the the one that were in the house_train_set. Let's apply the same methods on the house_test_data:

# %%
house_test_data[['pool_qc']] = house_test_data[['pool_qc']].fillna(value= 'No Pool')
house_test_data[['misc_feature']] = house_test_data[['misc_feature']].fillna(value= 'No extra features')
house_test_data[['alley']] = house_test_data[['alley']].fillna(value= 'No alley')
house_test_data[['fence']] = house_test_data[['fence']].fillna(value= 'No fence')
house_test_data[['fireplace_qu']] = house_test_data[['fireplace_qu']].fillna(value= 'No Fireplace')
house_test_data['lot_frontage'].fillna(house_test_data['lot_frontage'].mean(), inplace=True)
house_test_data['lot_frontage'] = house_test_data['lot_frontage'].astype('float')
house_test_data[['garage_type']] = house_test_data[['garage_type']].fillna(value= 'No Garage')
house_test_data[['garage_yr_blt']] = house_test_data[['garage_yr_blt']].fillna(value= 0)
house_test_data['garage_yr_blt'] = house_test_data['garage_yr_blt'].astype('float')
house_test_data[['garage_finish']] = house_test_data[['garage_finish']].fillna(value= 'No Garage')
house_test_data[['garage_qual']] = house_test_data[['garage_qual']].fillna(value= 'No Garage')
house_test_data.drop('garage_cond', axis=1, inplace=True)
house_test_data['bsmt_exposure'] = house_test_data['bsmt_exposure'].replace(['No'],'No exposure')
house_test_data[['bsmt_exposure']] = house_test_data[['bsmt_exposure']].fillna(value= 'No basement')
house_test_data.rename(columns={'bsmt_qual':'bsmt_height'}, inplace=True)
house_test_data[['bsmt_height']] = house_test_data[['bsmt_height']].fillna(value= 'No basement')
house_test_data[['bsmt_cond']] = house_test_data[['bsmt_cond']].fillna(value= 'No basement')
house_test_data[['mas_vnr_type']] = house_test_data[['mas_vnr_type']].fillna(value= 'None')
house_test_data[['mas_vnr_area']] = house_test_data[['mas_vnr_area']].fillna(value=0)
house_test_data['mas_vnr_area'] = house_test_data['mas_vnr_area'].astype('float')
house_test_data[['bsmtfin_type_2']] = house_test_data[['bsmtfin_type_2']].fillna(value= 'No basement')
house_test_data[['bsmtfin_type_1']] = house_test_data[['bsmtfin_type_1']].fillna(value= 'No basement')

# %% [markdown]
# Done! Let's see how many nulls are left:

# %%
house_test_data.isnull().sum()
# Out:
# id                 0
# pid                0
# ms_subclass        0
# ms_zoning          0
# lot_frontage       0
# lot_area           0
# street             0
# alley              0
# lot_shape          0
# land_contour       0
# utilities          0
# lot_config         0
# land_slope         0
# neighborhood       0
# condition_1        0
# condition_2        0
# bldg_type          0
# house_style        0
# overall_qual       0
# overall_cond       0
# year_built         0
# year_remod/add     0
# roof_style         0
# roof_matl          0
# exterior_1st       0
# exterior_2nd       0
# mas_vnr_type       0
# mas_vnr_area       0
# exter_qual         0
# exter_cond         0
# foundation         0
# bsmt_height        0
# bsmt_cond          0
# bsmt_exposure      0
# bsmtfin_type_1     0
# bsmtfin_sf_1       0
# bsmtfin_type_2     0
# bsmtfin_sf_2       0
# bsmt_unf_sf        0
# total_bsmt_sf      0
# heating            0
# heating_qc         0
# central_air        0
# electrical         1
# 1st_flr_sf         0
# 2nd_flr_sf         0
# low_qual_fin_sf    0
# gr_liv_area        0
# bsmt_full_bath     0
# bsmt_half_bath     0
# full_bath          0
# half_bath          0
# bedroom_abvgr      0
# kitchen_abvgr      0
# kitchen_qual       0
# totrms_abvgrd      0
# functional         0
# fireplaces         0
# fireplace_qu       0
# garage_type        0
# garage_yr_blt      0
# garage_finish      0
# garage_cars        0
# garage_area        0
# garage_qual        0
# paved_drive        0
# wood_deck_sf       0
# open_porch_sf      0
# enclosed_porch     0
# 3ssn_porch         0
# screen_porch       0
# pool_area          0
# pool_qc            0
# fence              0
# misc_feature       0
# misc_val           0
# mo_sold            0
# yr_sold            0
# sale_type          0
# dtype: int64

# %% [markdown]
# Only one null left on the electrical column. Since I can't drop any rows on the house_test_data; I will fill this null with 'No data'

# %%
house_test_data[['electrical']] = house_test_data[['electrical']].fillna(value= 'No data')

# %% [markdown]
# We can now save the house_test_data to a csv file. I will use this file to test the models I will build and for the kaggle submissions.

# %%
house_test_data.to_csv('datasets/house_test_data.csv')

# %% [markdown]
# # Step 2 : Exploratory Analysis

# %% [markdown]
# We are trying to predict the price of the houses so it is useful to observe the distribution of price in the dataset :

# %%
plt.figure(figsize=(12, 8))
plt.hist(house_train_set['saleprice'])
plt.title('Distribution of Houses Sale Price', fontsize=20)
plt.xlabel('Sale Price in $', fontsize=15)
plt.ylabel('Number of Houses', fontsize=15);

# %% [markdown]
# As seen above; the distribution of house prices is right-skewed. The prices are not normally distributed since they are centered around the mean. We have very few houses below 100,000 dollars and most houses are between 100,000 dollars and 200,000 dollars. Understandably, the higher prices have fewer houses but are present.

# %% [markdown]
# Let's observe the maximum and minimum values as well as other statistics:

# %%
house_train_set['saleprice'].describe().T
# Out:
# count      2048.000000
# mean     181484.252441
# std       79248.657891
# min       12789.000000
# 25%      129837.500000
# 50%      162500.000000
# 75%      214000.000000
# max      611657.000000
# Name: saleprice, dtype: float64

# %% [markdown]
# The average price of a house in this dataset is 181,484 dollars and I am confident to say that 95% of the houses are between 22,986 and 339,981 dollars based on the standard deviation. The minimum value for sale price is 12,789 dollars and the most expensive house is at 611,657 dollars.

# %% [markdown]
# Now that we have a better understanding of the house prices in this dataset; let's explore some relationship between the features and the price. Let's focus on the numerical columns first and visualize a heatmap to understand their correlation with the sale price:

# %%
numerical_features = house_train_set[['pid', 'ms_subclass', 'lot_frontage', 'lot_area','overall_qual', 'overall_cond', 'year_built',\
                        'year_remod/add', 'mas_vnr_area', 'bsmtfin_sf_1', 'bsmtfin_sf_2', 'bsmt_unf_sf', 'total_bsmt_sf',\
                          '1st_flr_sf', '2nd_flr_sf', 'low_qual_fin_sf', 'gr_liv_area', 'bsmt_full_bath', 'full_bath',\
                          'half_bath', 'bedroom_abvgr', 'kitchen_abvgr', 'totrms_abvgrd', 'fireplaces', 'garage_yr_blt',\
                          'garage_cars', 'garage_area', 'wood_deck_sf', 'open_porch_sf', 'enclosed_porch', '3ssn_porch',\
                          'screen_porch', 'pool_area', 'misc_val', 'mo_sold', 'yr_sold', 'saleprice']]

# %%
corr = numerical_features.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
plt.figure(figsize=(30, 30))
sns.heatmap(corr, annot=True,
cmap='coolwarm', vmin=-1, vmax=1, mask=mask)
# Out:
# <AxesSubplot:>

# %% [markdown]
# If we look at the numerical features only and based on the heatmap above; the 5 columns with the highest correlation to sale price are overall_qual, gr_liv_area, garage_area and garage_cars, total_bsmt_sf and 1st_flr_sf.
# These findings make a lot of sense especially regarding the overall quality of the houses, the square footage of the above ground living area, basement and first floor as well as the garage.
# Let's closely look at those relationship on a 1 by 1 basis with a few scatterplots:

# %%
plt.figure(figsize=(12, 8))
plt.scatter(house_train_set['overall_qual'], house_train_set['saleprice'], color = "red")
plt.title('Overall Quality vs Sale Price', fontsize=20)
plt.ylabel('Sale Price in $', fontsize = 15)
plt.xlabel('Overall Quality Rating', fontsize = 15);

# %% [markdown]
# We clearly can observe the relationship between overall quality and sale price as the price increase when the overall quality is higher. This feature is definitely influential on the final price of a house.

# %% [markdown]
# Now let's observe the relationship between gr_liv_area which is the square footage of the above ground living area and the sale price with a scatter plot:

# %%
plt.figure(figsize=(12, 8))
plt.scatter(house_train_set['gr_liv_area'], house_train_set['saleprice'], color = "green")
plt.title('Above Ground Living Area vs Sale Price', fontsize=20)
plt.ylabel('Sale Price in $', fontsize = 15)
plt.xlabel('Above Ground Living Area in Sq ft', fontsize = 15);

# %% [markdown]
# As we can see above, there is a visible trend. When the above ground living area increase in space; there is an increase in price. We can also observe some outliers notably two above 5000 sqft. Most houses between 100,000 and 200,000 dollars as noted earlier are between 1000 and 2000 sq ft(above ground living area)

# %% [markdown]
# Let's look at the relationship between garage area and sale price:

# %%
plt.figure(figsize=(12, 8))
plt.scatter(house_train_set['garage_area'], house_train_set['saleprice'], color = "green")
plt.title('Garage Area vs Sale Price', fontsize=20)
plt.ylabel('Sale Price in $', fontsize = 15)
plt.xlabel('Garage Size of in Sq ft', fontsize = 15);

# %% [markdown]
# Generally, as the size of the garage increase, the price of the houses increase as well. In this case we can observe a number of houses with no garage as well as outliers with a garage size above 1200 square feet. The most expensive houses don't have the biggest garage in the set. While it is an important factor in the final price of the house, it has to be noted that up to a certain point it is positively affecting the price of a house and then after that it doesn't add much.

# %% [markdown]
# Let's look at the relationship between the total basement sq ft and the sale price:

# %%
plt.figure(figsize=(12, 8))
plt.scatter(house_train_set['total_bsmt_sf'], house_train_set['saleprice'], color = "green")
plt.title('Total Basement in Sqft vs Sale Price', fontsize=20)
plt.ylabel('Sale Price in $', fontsize = 15)
plt.xlabel('Basement Area in Sq ft', fontsize = 15);

# %% [markdown]
# A visible trend is also present here; the price increase when the basement area increase. Most value are between 1000 and 2000 sqft. The most expensive houses have a basement area greater than 2000 sqft which illustrate the trend. The price decrease after 3000 sqft and we also two notable outliers with a basement area greater than 5000 sqft.
# Just like the garage area, the basement area is influential on the final price but after a certain point it doesn't make the price higher. In contrary it might result in price decrease.

# %% [markdown]
# Now let's look at the first floor area vs the sale price:

# %%
plt.figure(figsize=(12, 8))
plt.scatter(house_train_set['1st_flr_sf'], house_train_set['saleprice'], color = "green")
plt.title('First Floor Area in Sqft vs Sale Price', fontsize=20)
plt.ylabel('Sale Price in $', fontsize = 15)
plt.xlabel('First Floor Area in Sq ft', fontsize = 15);

# %% [markdown]
# The trend is visible and very similar to the one observed in the previous scatterplot(basement area vs sale price).
# Obviously we have no value at 0 sqft since we are now talking about the living area. As the first floor area increase in space, the price increase as well. Most Values are between 1000 and 2000 sqft with the highest values around 2000 sqft. After this point the price decrease and the houses with a very large 1st floor area (more than 4000 sqft) have a significantly lower price. While the 1st floor  area is an important factor on the final price, the biggest space don't equal to the highest price.

# %% [markdown]
# # Categorical values

# %% [markdown]
# Up until now we only observed the numerical features. While some of them showed a strong correlation with the final prices of the houses, they are many more features present capable of influencing the price.
# Does the house have an alley, what about the neighborhood ? What type of house is it ? Does it have a fireplace or a pool ? Several methods can be used to determine the best categorical features to use in our model.
# I choose to dummify most of them and look at the correlation between only the categorical features and the sale price.
# I will then choose the 4 most correlated features and use them in concurrence with the numerical features to fit our model.

# %%
house_train_set.dtypes
# Out:
# id                   int64
# pid                  int64
# ms_subclass          int64
# ms_zoning           object
# lot_frontage       float64
# lot_area             int64
# street              object
# alley               object
# lot_shape           object
# land_contour        object
# utilities           object
# lot_config          object
# land_slope          object
# neighborhood        object
# condition_1         object
# condition_2         object
# bldg_type           object
# house_style         object
# overall_qual         int64
# overall_cond         int64
# year_built           int64
# year_remod/add       int64
# roof_style          object
# roof_matl           object
# exterior_1st        object
# exterior_2nd        object
# mas_vnr_type        object
# mas_vnr_area       float64
# exter_qual          object
# exter_cond          object
# foundation          object
# bsmt_height         object
# bsmt_cond           object
# bsmt_exposure       object
# bsmtfin_type_1      object
# bsmtfin_sf_1       float64
# bsmtfin_type_2      object
# bsmtfin_sf_2       float64
# bsmt_unf_sf        float64
# total_bsmt_sf      float64
# heating             object
# heating_qc          object
# central_air         object
# electrical          object
# 1st_flr_sf           int64
# 2nd_flr_sf           int64
# low_qual_fin_sf      int64
# gr_liv_area          int64
# bsmt_full_bath     float64
# bsmt_half_bath     float64
# full_bath            int64
# half_bath            int64
# bedroom_abvgr        int64
# kitchen_abvgr        int64
# kitchen_qual        object
# totrms_abvgrd        int64
# functional          object
# fireplaces           int64
# fireplace_qu        object
# garage_type         object
# garage_yr_blt      float64
# garage_finish       object
# garage_cars        float64
# garage_area        float64
# garage_qual         object
# paved_drive         object
# wood_deck_sf         int64
# open_porch_sf        int64
# enclosed_porch       int64
# 3ssn_porch           int64
# screen_porch         int64
# pool_area            int64
# pool_qc             object
# fence               object
# misc_feature        object
# misc_val             int64
# mo_sold              int64
# yr_sold              int64
# sale_type           object
# saleprice            int64
# dtype: object

# %%
categorical_features = house_train_set[['ms_zoning', 'street', 'alley', 'lot_shape','land_contour', 'utilities', 'lot_config',\
                        'land_slope', 'neighborhood', 'condition_1', 'condition_2', 'bldg_type', 'house_style',\
                          'roof_style', 'roof_matl', 'exterior_1st', 'exterior_2nd', 'mas_vnr_type', 'exter_qual',\
                          'exter_cond', 'foundation', 'bsmt_height', 'bsmt_cond', 'bsmt_exposure', 'bsmtfin_type_1',\
                          'bsmtfin_type_2', 'heating', 'heating_qc', 'central_air', 'electrical', 'kitchen_qual',\
                          'functional', 'fireplace_qu', 'garage_type', 'garage_finish', 'garage_qual', 'paved_drive',\
                                       'pool_qc', 'fence', 'misc_feature', 'sale_type']]

# %%
encoded_values = pd.get_dummies(categorical_features, drop_first=True)

# %%
categorical_corr = pd.concat([encoded_values, house_train_set['saleprice']], axis = 1)

# %%
pd.set_option("display.max_rows",10, "display.max_columns", None)

# %%
categorical_corr.corr(method='pearson')
# Out:
#                    ms_zoning_C (all)  ms_zoning_FV  ms_zoning_I (all)  \
# ms_zoning_C (all)           1.000000     -0.022040          -0.002139
# ms_zoning_FV               -0.022040      1.000000          -0.005034
# ms_zoning_I (all)          -0.002139     -0.005034           1.000000
# ms_zoning_RH               -0.008028     -0.018896          -0.001834
# ms_zoning_RL               -0.182096     -0.428590          -0.041592
# ...                              ...           ...                ...
# sale_type_ConLw            -0.004787     -0.011268          -0.001093
# sale_type_New              -0.028171      0.194184          -0.006434
# sale_type_Oth              -0.004281     -0.010076          -0.000978
# sale_type_WD               -0.022683     -0.145097          -0.056840
# saleprice                  -0.126380      0.106749          -0.034553
#
#                    ms_zoning_RH  ms_zoning_RL  ms_zoning_RM  street_Pave  \
# ms_zoning_C (all)     -0.008028     -0.182096     -0.041179    -0.256129
# ms_zoning_FV          -0.018896     -0.428590     -0.096921     0.013338
# ms_zoning_I (all)     -0.001834     -0.041592     -0.009405    -0.377410
# ms_zoning_RH           1.000000     -0.156118     -0.035304     0.004859
# ms_zoning_RL          -0.156118      1.000000     -0.800764     0.069824
# ...                         ...           ...           ...          ...
# sale_type_ConLw       -0.004104     -0.021463      0.033871     0.002897
# sale_type_New         -0.024152     -0.003362     -0.098630     0.017049
# sale_type_Oth         -0.003670     -0.003180      0.011870     0.002591
# sale_type_WD           0.014717      0.013124      0.077206     0.001995
# saleprice             -0.034162      0.230202     -0.280768     0.069912
#
#                    alley_No alley  alley_Pave  lot_shape_IR2  lot_shape_IR3  \
# ms_zoning_C (all)       -0.034333    0.046934      -0.016075      -0.006429
# ms_zoning_FV            -0.277865    0.492236       0.017961      -0.015132
# ms_zoning_I (all)        0.005987   -0.003672      -0.003672      -0.001468
# ms_zoning_RH            -0.024491    0.059532       0.096189      -0.005512
# ms_zoning_RL             0.374324   -0.268869       0.029970      -0.000322
# ...                           ...         ...            ...            ...
# sale_type_ConLw          0.013401   -0.008218       0.052985      -0.003287
# sale_type_New           -0.000451    0.075442      -0.003341       0.008166
# sale_type_Oth            0.011983   -0.007349      -0.007349      -0.002939
# sale_type_WD             0.037871   -0.069531       0.010946       0.003980
# saleprice                0.135227   -0.014571       0.110016       0.009809
#
#                    lot_shape_Reg  land_contour_HLS  land_contour_Low  \
# ms_zoning_C (all)       0.063308          0.005399          0.021353
# ms_zoning_FV            0.028916         -0.047394         -0.033355
# ms_zoning_I (all)       0.016872         -0.004599         -0.003237
# ms_zoning_RH            0.001896          0.012447         -0.012150
# ms_zoning_RL           -0.246853          0.033782          0.053168
# ...                          ...               ...               ...
# sale_type_ConLw        -0.003265         -0.010294         -0.007245
# sale_type_New          -0.060712          0.103622         -0.042632
# sale_type_Oth          -0.012092         -0.009205         -0.006478
# sale_type_WD            0.023869         -0.056788          0.046864
# saleprice              -0.306704          0.212396          0.032955
#
#                    land_contour_Lvl  utilities_NoSeWa  utilities_NoSewr  \
# ms_zoning_C (all)         -0.034907         -0.002139         -0.002139
# ms_zoning_FV               0.076577         -0.005034         -0.005034
# ms_zoning_I (all)          0.007431         -0.000489          1.000000
# ms_zoning_RH              -0.070195         -0.001834         -0.001834
# ms_zoning_RL              -0.026543          0.011746         -0.041592
# ...                             ...               ...               ...
# sale_type_ConLw           -0.016121         -0.001093         -0.001093
# sale_type_New             -0.022587         -0.006434         -0.006434
# sale_type_Oth              0.014873         -0.000978         -0.000978
# sale_type_WD              -0.011104         -0.056840         -0.056840
# saleprice                 -0.092855         -0.012270         -0.034553
#
#                    lot_config_CulDSac  lot_config_FR2  lot_config_FR3  \
# ms_zoning_C (all)           -0.025296       -0.016811       -0.006060
# ms_zoning_FV                -0.041107        0.027293       -0.014263
# ms_zoning_I (all)           -0.005778       -0.003840       -0.001384
# ms_zoning_RH                -0.021688        0.091008       -0.005195
# ms_zoning_RL                 0.129288        0.001488       -0.023391
# ...                               ...             ...             ...
# sale_type_ConLw              0.027503       -0.008594       -0.003098
# sale_type_New               -0.001743       -0.018207       -0.018230
# sale_type_Oth               -0.011564       -0.007685       -0.002770
# sale_type_WD                -0.004688        0.007551        0.024351
# saleprice                    0.162530       -0.014868        0.025345
#
#                    lot_config_Inside  land_slope_Mod  land_slope_Sev  \
# ms_zoning_C (all)          -0.010651        0.054842       -0.006779
# ms_zoning_FV                0.045750       -0.048260       -0.015954
# ms_zoning_I (all)           0.013343       -0.004683       -0.001548
# ms_zoning_RH               -0.003492       -0.017579       -0.005811
# ms_zoning_RL               -0.099757        0.008012        0.037225
# ...                              ...             ...             ...
# sale_type_ConLw            -0.014861       -0.010482       -0.003465
# sale_type_New               0.015357       -0.025795       -0.020392
# sale_type_Oth              -0.023288       -0.009374       -0.003099
# sale_type_WD                0.000499        0.039624        0.027239
# saleprice                  -0.083650        0.061926        0.011594
#
#                    neighborhood_Blueste  neighborhood_BrDale  \
# ms_zoning_C (all)             -0.005245            -0.009364
# ms_zoning_FV                  -0.012346            -0.022040
# ms_zoning_I (all)             -0.001198            -0.002139
# ms_zoning_RH                  -0.004497            -0.008028
# ms_zoning_RL                  -0.102003            -0.182096
# ...                                 ...                  ...
# sale_type_ConLw               -0.002682            -0.004787
# sale_type_New                 -0.015780            -0.028171
# sale_type_Oth                 -0.002398            -0.004281
# sale_type_WD                  -0.005668            -0.007605
# saleprice                     -0.025258            -0.095406
#
#                    neighborhood_BrkSide  neighborhood_ClearCr  \
# ms_zoning_C (all)             -0.018867             -0.011185
# ms_zoning_FV                  -0.044406             -0.026325
# ms_zoning_I (all)             -0.004309             -0.002555
# ms_zoning_RH                  -0.016175             -0.009589
# ms_zoning_RL                  -0.178688              0.061423
# ...                                 ...                   ...
# sale_type_ConLw                0.043031             -0.005718
# sale_type_New                 -0.056758             -0.033648
# sale_type_Oth                 -0.008625             -0.005113
# sale_type_WD                   0.060423              0.019598
# saleprice                     -0.132445              0.052527
#
#                    neighborhood_CollgCr  neighborhood_Crawfor  \
# ms_zoning_C (all)             -0.030039             -0.018338
# ms_zoning_FV                  -0.070701             -0.043162
# ms_zoning_I (all)             -0.006861             -0.004189
# ms_zoning_RH                  -0.025754              0.016671
# ms_zoning_RL                   0.131669              0.049179
# ...                                 ...                   ...
# sale_type_ConLw                0.019588             -0.009375
# sale_type_New                  0.044581             -0.015385
# sale_type_Oth                 -0.013732             -0.008383
# sale_type_WD                   0.003281              0.010475
# saleprice                      0.082328              0.058403
#
#                    neighborhood_Edwards  neighborhood_Gilbert  \
# ms_zoning_C (all)             -0.026413             -0.023712
# ms_zoning_FV                  -0.062167             -0.055809
# ms_zoning_I (all)             -0.006033             -0.005416
# ms_zoning_RH                   0.000683             -0.020329
# ms_zoning_RL                   0.098665              0.130215
# ...                                 ...                   ...
# sale_type_ConLw                0.025447             -0.012122
# sale_type_New                 -0.050809              0.054606
# sale_type_Oth                  0.074998             -0.010840
# sale_type_WD                  -0.030437             -0.011029
# saleprice                     -0.179408              0.023950
#
#                    neighborhood_Greens  neighborhood_GrnHill  \
# ms_zoning_C (all)            -0.003706             -0.003026
# ms_zoning_FV                 -0.008724             -0.007121
# ms_zoning_I (all)            -0.000847             -0.000691
# ms_zoning_RH                 -0.003178             -0.002594
# ms_zoning_RL                  0.020354             -0.058834
# ...                                ...                   ...
# sale_type_ConLw              -0.001895             -0.001547
# sale_type_New                -0.011150             -0.009102
# sale_type_Oth                -0.001694             -0.001383
# sale_type_WD                  0.014894              0.012158
# saleprice                     0.003472              0.038876
#
#                    neighborhood_IDOTRR  neighborhood_Landmrk  \
# ms_zoning_C (all)             0.522172             -0.002139
# ms_zoning_FV                 -0.042208             -0.005034
# ms_zoning_I (all)             0.119267             -0.000489
# ms_zoning_RH                 -0.015375              0.266411
# ms_zoning_RL                 -0.348727             -0.041592
# ...                                ...                   ...
# sale_type_ConLw               0.046056             -0.001093
# sale_type_New                -0.053949             -0.006434
# sale_type_Oth                -0.008198             -0.000978
# sale_type_WD                 -0.000552              0.008595
# saleprice                    -0.189727             -0.012410
#
#                    neighborhood_MeadowV  neighborhood_Mitchel  \
# ms_zoning_C (all)             -0.010537             -0.019763
# ms_zoning_FV                  -0.024802             -0.046515
# ms_zoning_I (all)             -0.002407             -0.004514
# ms_zoning_RH                  -0.009034             -0.016944
# ms_zoning_RL                  -0.204911              0.060449
# ...                                 ...                   ...
# sale_type_ConLw               -0.005387             -0.010103
# sale_type_New                 -0.031700             -0.050173
# sale_type_Oth                 -0.004817             -0.009035
# sale_type_WD                   0.042344              0.035175
# saleprice                     -0.111674             -0.035643
#
#                    neighborhood_NAmes  neighborhood_NPkVill  \
# ms_zoning_C (all)           -0.040869             -0.008853
# ms_zoning_FV                -0.096191             -0.020838
# ms_zoning_I (all)           -0.009335             -0.002022
# ms_zoning_RH                 0.031099             -0.007590
# ms_zoning_RL                 0.211285              0.048619
# ...                               ...                   ...
# sale_type_ConLw             -0.020893             -0.004526
# sale_type_New               -0.122946             -0.026634
# sale_type_Oth               -0.018683             -0.004047
# sale_type_WD                 0.059361              0.035576
# saleprice                   -0.189652             -0.047353
#
#                    neighborhood_NWAmes  neighborhood_NoRidge  \
# ms_zoning_C (all)            -0.020382             -0.014991
# ms_zoning_FV                 -0.047973             -0.035284
# ms_zoning_I (all)            -0.004655             -0.003424
# ms_zoning_RH                 -0.017475             -0.012853
# ms_zoning_RL                  0.111933              0.082327
# ...                                ...                   ...
# sale_type_ConLw              -0.010420             -0.007664
# sale_type_New                -0.061317             -0.045099
# sale_type_Oth                -0.009318             -0.006853
# sale_type_WD                  0.031732              0.060241
# saleprice                     0.034919              0.263598
#
#                    neighborhood_NridgHt  neighborhood_OldTown  \
# ms_zoning_C (all)             -0.024355             -0.028456
# ms_zoning_FV                  -0.057323             -0.066975
# ms_zoning_I (all)             -0.005563             -0.006499
# ms_zoning_RH                  -0.020880             -0.024396
# ms_zoning_RL                   0.128770             -0.431455
# ...                                 ...                   ...
# sale_type_ConLw               -0.012451              0.022009
# sale_type_New                  0.241903             -0.085605
# sale_type_Oth                 -0.011134              0.027853
# sale_type_WD                  -0.164751              0.060938
# saleprice                      0.449007             -0.208617
#
#                    neighborhood_SWISU  neighborhood_Sawyer  \
# ms_zoning_C (all)           -0.012192            -0.023165
# ms_zoning_FV                -0.028695            -0.054522
# ms_zoning_I (all)           -0.002785            -0.005291
# ms_zoning_RH                 0.228461            -0.019860
# ms_zoning_RL                 0.019447             0.116805
# ...                               ...                  ...
# sale_type_ConLw             -0.006233            -0.011843
# sale_type_New               -0.036677            -0.069688
# sale_type_Oth               -0.005573             0.038257
# sale_type_WD                 0.048991             0.067547
# saleprice                   -0.074301            -0.133856
#
#                    neighborhood_SawyerW  neighborhood_Somerst  \
# ms_zoning_C (all)             -0.020382             -0.025193
# ms_zoning_FV                  -0.047973              0.874843
# ms_zoning_I (all)             -0.004655             -0.005754
# ms_zoning_RH                   0.041291             -0.021599
# ms_zoning_RL                   0.100248             -0.349755
# ...                                 ...                   ...
# sale_type_ConLw               -0.010420             -0.012879
# sale_type_New                 -0.025232              0.237628
# sale_type_Oth                 -0.009318             -0.011517
# sale_type_WD                   0.038900             -0.177419
# saleprice                      0.016684              0.150167
#
#                    neighborhood_StoneBr  neighborhood_Timber  \
# ms_zoning_C (all)             -0.013305            -0.014991
# ms_zoning_FV                  -0.031316            -0.035284
# ms_zoning_I (all)             -0.003039            -0.003424
# ms_zoning_RH                  -0.011407            -0.012853
# ms_zoning_RL                   0.073068             0.082327
# ...                                 ...                  ...
# sale_type_ConLw               -0.006802            -0.007664
# sale_type_New                  0.108283             0.063138
# sale_type_Oth                 -0.006083            -0.006853
# sale_type_WD                  -0.075079            -0.044864
# saleprice                      0.257176             0.116473
#
#                    neighborhood_Veenker  condition_1_Feedr  condition_1_Norm  \
# ms_zoning_C (all)             -0.008853           0.091106         -0.035045
# ms_zoning_FV                  -0.020838          -0.053739          0.084666
# ms_zoning_I (all)             -0.002022          -0.005215          0.008850
# ms_zoning_RH                  -0.007590           0.059968         -0.035468
# ms_zoning_RL                   0.048619           0.030489         -0.001095
# ...                                 ...                ...               ...
# sale_type_ConLw               -0.004526          -0.011672         -0.066204
# sale_type_New                 -0.026634          -0.019843          0.021666
# sale_type_Oth                 -0.004047          -0.010438          0.017714
# sale_type_WD                   0.019643           0.020603         -0.004907
# saleprice                      0.083241          -0.112169          0.109877
#
#                    condition_1_PosA  condition_1_PosN  condition_1_RRAe  \
# ms_zoning_C (all)         -0.007429         -0.011185         -0.009850
# ms_zoning_FV              -0.017486         -0.026325         -0.023183
# ms_zoning_I (all)         -0.001697         -0.002555         -0.002250
# ms_zoning_RH              -0.006369         -0.009589         -0.008444
# ms_zoning_RL               0.040798          0.061423          0.019001
# ...                             ...               ...               ...
# sale_type_ConLw           -0.003798          0.081027         -0.005035
# sale_type_New              0.025329          0.014207         -0.011570
# sale_type_Oth             -0.003396         -0.005113         -0.004503
# sale_type_WD              -0.008027         -0.018423         -0.003468
# saleprice                  0.070977          0.106949         -0.053698
#
#                    condition_1_RRAn  condition_1_RRNe  condition_1_RRNn  \
# ms_zoning_C (all)         -0.012944         -0.003706         -0.005245
# ms_zoning_FV              -0.013306         -0.008724         -0.012346
# ms_zoning_I (all)         -0.002957         -0.000847         -0.001198
# ms_zoning_RH              -0.011098         -0.003178         -0.004497
# ms_zoning_RL               0.026252         -0.010455         -0.014797
# ...                             ...               ...               ...
# sale_type_ConLw            0.068674         -0.001895         -0.002682
# sale_type_New              0.044132         -0.011150         -0.015780
# sale_type_Oth             -0.005917         -0.001694         -0.002398
# sale_type_WD              -0.057987          0.014894          0.021078
# saleprice                 -0.014991         -0.025074          0.011442
#
#                    condition_2_Feedr  condition_2_Norm  condition_2_PosA  \
# ms_zoning_C (all)           0.062571         -0.034519         -0.003706
# ms_zoning_FV               -0.016737          0.025827         -0.008724
# ms_zoning_I (all)          -0.001624          0.002506         -0.000847
# ms_zoning_RH               -0.006097          0.009408         -0.003178
# ms_zoning_RL               -0.057676          0.055512         -0.010455
# ...                              ...               ...               ...
# sale_type_ConLw            -0.003635          0.005610         -0.001895
# sale_type_New              -0.021392         -0.015744          0.083996
# sale_type_Oth              -0.003251          0.005016         -0.001694
# sale_type_WD               -0.010980          0.020465         -0.060701
# saleprice                  -0.048511         -0.009747          0.101124
#
#                    condition_2_PosN  condition_2_RRAe  condition_2_RRAn  \
# ms_zoning_C (all)         -0.003706         -0.002139         -0.002139
# ms_zoning_FV              -0.008724         -0.005034         -0.005034
# ms_zoning_I (all)         -0.000847         -0.000489         -0.000489
# ms_zoning_RH              -0.003178         -0.001834         -0.001834
# ms_zoning_RL               0.020354          0.011746          0.011746
# ...                             ...               ...               ...
# sale_type_ConLw           -0.001895         -0.001093         -0.001093
# sale_type_New              0.036423         -0.006434         -0.006434
# sale_type_Oth             -0.001694         -0.000978         -0.000978
# sale_type_WD              -0.022903          0.008595          0.008595
# saleprice                  0.103541          0.002376         -0.012436
#
#                    condition_2_RRNn  bldg_type_2fmCon  bldg_type_Duplex  \
# ms_zoning_C (all)         -0.003026          0.054075         -0.018867
# ms_zoning_FV              -0.007121         -0.034524         -0.044406
# ms_zoning_I (all)         -0.000691         -0.003350         -0.004309
# ms_zoning_RH              -0.002594          0.107402          0.015374
# ms_zoning_RL              -0.058834         -0.086440          0.040877
# ...                             ...               ...               ...
# sale_type_ConLw           -0.001547         -0.007499         -0.009645
# sale_type_New             -0.009102         -0.044127         -0.056758
# sale_type_Oth             -0.001383         -0.006706          0.050255
# sale_type_WD               0.012158          0.029677          0.045031
# saleprice                 -0.033438         -0.111548         -0.103817
#
#                    bldg_type_Twnhs  bldg_type_TwnhsE  house_style_1.5Unf  \
# ms_zoning_C (all)        -0.018069         -0.028266            0.059303
# ms_zoning_FV              0.119945          0.201597           -0.017486
# ms_zoning_I (all)        -0.004127         -0.006456           -0.001697
# ms_zoning_RH              0.017352          0.063841           -0.006369
# ms_zoning_RL             -0.227293         -0.195026           -0.082711
# ...                            ...               ...                 ...
# sale_type_ConLw          -0.009237         -0.014450           -0.003798
# sale_type_New            -0.054358          0.070456           -0.022349
# sale_type_Oth            -0.008260         -0.012922           -0.003396
# sale_type_WD              0.032551         -0.036809            0.010913
# saleprice                -0.114030          0.062041           -0.066877
#
#                    house_style_1Story  house_style_2.5Fin  house_style_2.5Unf  \
# ms_zoning_C (all)           -0.008216           -0.005245           -0.008028
# ms_zoning_FV                -0.054724           -0.012346           -0.018896
# ms_zoning_I (all)            0.021401           -0.001198           -0.001834
# ms_zoning_RH                -0.014533            0.105147           -0.006883
# ms_zoning_RL                 0.195152           -0.058400           -0.070315
# ...                               ...                 ...                 ...
# sale_type_ConLw             -0.031293           -0.002682            0.115976
# sale_type_New                0.063429           -0.015780           -0.024152
# sale_type_Oth                0.042834           -0.002398           -0.003670
# sale_type_WD                -0.081472            0.021078            0.014717
# saleprice                   -0.021885            0.042543            0.010787
#
#                    house_style_2Story  house_style_SFoyer  house_style_SLvl  \
# ms_zoning_C (all)           -0.028450           -0.015308         -0.021224
# ms_zoning_FV                 0.156594           -0.036030         -0.049955
# ms_zoning_I (all)           -0.014177           -0.003496         -0.004848
# ms_zoning_RH                 0.011983           -0.013124         -0.018197
# ms_zoning_RL                -0.086941           -0.007553          0.082773
# ...                               ...                 ...               ...
# sale_type_ConLw             -0.009961           -0.007826         -0.010851
# sale_type_New                0.049482           -0.034263         -0.063850
# sale_type_Oth               -0.028375           -0.006998         -0.009703
# sale_type_WD                 0.014042            0.033414          0.043842
# saleprice                    0.202542           -0.064173         -0.042176
#
#                    roof_style_Gable  roof_style_Gambrel  roof_style_Hip  \
# ms_zoning_C (all)         -0.024870            0.059303        0.004083
# ms_zoning_FV               0.068013           -0.017486       -0.060346
# ms_zoning_I (all)          0.011428           -0.001697       -0.010838
# ms_zoning_RH               0.013845            0.071275       -0.025692
# ms_zoning_RL              -0.118800           -0.036395        0.120496
# ...                             ...                 ...             ...
# sale_type_ConLw            0.025578           -0.003798       -0.024259
# sale_type_New             -0.076930           -0.022349        0.091979
# sale_type_Oth              0.022872           -0.003396       -0.021693
# sale_type_WD               0.057606            0.029853       -0.076262
# saleprice                 -0.249497           -0.041934        0.265409
#
#                    roof_style_Mansard  roof_style_Shed  roof_matl_CompShg  \
# ms_zoning_C (all)            0.081598        -0.003706           0.010973
# ms_zoning_FV                -0.013338        -0.008724           0.025827
# ms_zoning_I (all)           -0.001294        -0.000847           0.002506
# ms_zoning_RH                -0.004859        -0.003178           0.009408
# ms_zoning_RL                -0.009257         0.020354          -0.049736
# ...                               ...              ...                ...
# sale_type_ConLw             -0.002897        -0.001895           0.005610
# sale_type_New               -0.017049        -0.011150           0.016759
# sale_type_Oth               -0.002591        -0.001694           0.005016
# sale_type_WD                 0.022773         0.014894          -0.018271
# saleprice                   -0.021319         0.013141          -0.069147
#
#                    roof_matl_Membran  roof_matl_Tar&Grv  roof_matl_WdShake  \
# ms_zoning_C (all)          -0.002139          -0.008312          -0.004281
# ms_zoning_FV               -0.005034          -0.019564          -0.010076
# ms_zoning_I (all)          -0.000489          -0.001899          -0.000978
# ms_zoning_RH               -0.001834          -0.007126          -0.003670
# ms_zoning_RL                0.011746           0.045647           0.023509
# ...                              ...                ...                ...
# sale_type_ConLw            -0.001093          -0.004249          -0.002188
# sale_type_New              -0.006434          -0.025006          -0.012878
# sale_type_Oth              -0.000978          -0.003800          -0.001957
# sale_type_WD                0.008595           0.033401          -0.015539
# saleprice                   0.016743           0.007009           0.046212
#
#                    roof_matl_WdShngl  exterior_1st_AsphShn  \
# ms_zoning_C (all)          -0.004787             -0.002139
# ms_zoning_FV               -0.011268             -0.005034
# ms_zoning_I (all)          -0.001093             -0.000489
# ms_zoning_RH               -0.004104             -0.001834
# ms_zoning_RL                0.002413             -0.041592
# ...                              ...                   ...
# sale_type_ConLw            -0.002447             -0.001093
# sale_type_New              -0.014402             -0.006434
# sale_type_Oth              -0.002188             -0.000978
# sale_type_WD                0.019237              0.008595
# saleprice                   0.098603             -0.027648
#
#                    exterior_1st_BrkComm  exterior_1st_BrkFace  \
# ms_zoning_C (all)             -0.003706              0.011892
# ms_zoning_FV                  -0.008724             -0.027946
# ms_zoning_I (all)             -0.000847             -0.003970
# ms_zoning_RH                  -0.003178             -0.014901
# ms_zoning_RL                   0.020354              0.048040
# ...                                 ...                   ...
# sale_type_ConLw               -0.001895             -0.008885
# sale_type_New                 -0.011150             -0.052285
# sale_type_Oth                 -0.001694             -0.007945
# sale_type_WD                  -0.022903              0.053224
# saleprice                     -0.024405              0.026230
#
#                    exterior_1st_CBlock  exterior_1st_CemntBd  \
# ms_zoning_C (all)            -0.003026             -0.020747
# ms_zoning_FV                 -0.007121              0.083189
# ms_zoning_I (all)            -0.000691             -0.004739
# ms_zoning_RH                 -0.002594             -0.017787
# ms_zoning_RL                 -0.021109             -0.156251
# ...                                ...                   ...
# sale_type_ConLw              -0.001547             -0.010606
# sale_type_New                -0.009102              0.159499
# sale_type_Oth                -0.001383             -0.009484
# sale_type_WD                  0.012158             -0.099994
# saleprice                    -0.034819              0.167623
#
#                    exterior_1st_HdBoard  exterior_1st_ImStucc  \
# ms_zoning_C (all)             -0.040089             -0.002139
# ms_zoning_FV                  -0.094356             -0.005034
# ms_zoning_I (all)             -0.009157             -0.000489
# ms_zoning_RH                  -0.017610             -0.001834
# ms_zoning_RL                   0.133511              0.011746
# ...                                 ...                   ...
# sale_type_ConLw                0.007487             -0.001093
# sale_type_New                 -0.120600             -0.006434
# sale_type_Oth                  0.012951             -0.000978
# sale_type_WD                   0.050712              0.008595
# saleprice                     -0.114521              0.022461
#
#                    exterior_1st_MetalSd  exterior_1st_Plywood  \
# ms_zoning_C (all)              0.054560             -0.007813
# ms_zoning_FV                   0.102589             -0.064259
# ms_zoning_I (all)             -0.009687             -0.006236
# ms_zoning_RH                   0.060350             -0.023407
# ms_zoning_RL                  -0.177327              0.140913
# ...                                 ...                   ...
# sale_type_ConLw                0.005230             -0.013957
# sale_type_New                 -0.078098             -0.082132
# sale_type_Oth                  0.040774             -0.012481
# sale_type_WD                   0.040674              0.059926
# saleprice                     -0.148547             -0.041767
#
#                    exterior_1st_Stone  exterior_1st_Stucco  \
# ms_zoning_C (all)           -0.003026            -0.011185
# ms_zoning_FV                -0.007121            -0.026325
# ms_zoning_I (all)           -0.000691            -0.002555
# ms_zoning_RH                -0.002594            -0.009589
# ms_zoning_RL                 0.016615            -0.062543
# ...                               ...                  ...
# sale_type_ConLw             -0.001547            -0.005718
# sale_type_New               -0.009102            -0.017696
# sale_type_Oth               -0.001383            -0.005113
# sale_type_WD                -0.034123             0.019598
# saleprice                    0.030392            -0.060938
#
#                    exterior_1st_VinylSd  exterior_1st_Wd Sdng  \
# ms_zoning_C (all)             -0.060905              0.051517
# ms_zoning_FV                   0.086299             -0.089699
# ms_zoning_I (all)             -0.016344              0.056121
# ms_zoning_RH                  -0.011766              0.019469
# ms_zoning_RL                   0.114453             -0.087923
# ...                                 ...                   ...
# sale_type_ConLw                0.004810              0.009536
# sale_type_New                  0.245242             -0.114649
# sale_type_Oth                 -0.009579             -0.017422
# sale_type_WD                  -0.132758              0.059869
# saleprice                      0.342441             -0.191735
#
#                    exterior_1st_WdShing  exterior_2nd_AsphShn  \
# ms_zoning_C (all)              0.020238             -0.003706
# ms_zoning_FV                  -0.018755             -0.008724
# ms_zoning_I (all)             -0.003313             -0.000847
# ms_zoning_RH                  -0.012435             -0.003178
# ms_zoning_RL                   0.031426             -0.010455
# ...                                 ...                   ...
# sale_type_ConLw               -0.007415             -0.001895
# sale_type_New                 -0.006400             -0.011150
# sale_type_Oth                 -0.006631             -0.001694
# sale_type_WD                   0.008980              0.014894
# saleprice                     -0.048937             -0.023861
#
#                    exterior_2nd_Brk Cmn  exterior_2nd_BrkFace  \
# ms_zoning_C (all)             -0.008853              0.027287
# ms_zoning_FV                  -0.020838             -0.029593
# ms_zoning_I (all)             -0.002022             -0.002872
# ms_zoning_RH                  -0.007590             -0.010779
# ms_zoning_RL                   0.048619              0.032160
# ...                                 ...                   ...
# sale_type_ConLw               -0.004526             -0.006428
# sale_type_New                 -0.026634             -0.037824
# sale_type_Oth                 -0.004047             -0.005748
# sale_type_WD                   0.019643              0.016584
# saleprice                     -0.047951              0.010673
#
#                    exterior_2nd_CBlock  exterior_2nd_CmentBd  \
# ms_zoning_C (all)            -0.002139             -0.020747
# ms_zoning_FV                 -0.005034              0.083189
# ms_zoning_I (all)            -0.000489             -0.004739
# ms_zoning_RH                 -0.001834             -0.017787
# ms_zoning_RL                  0.011746             -0.156251
# ...                                ...                   ...
# sale_type_ConLw              -0.001093             -0.010606
# sale_type_New                -0.006434              0.159499
# sale_type_Oth                -0.000978             -0.009484
# sale_type_WD                  0.008595             -0.099994
# saleprice                    -0.021337              0.157100
#
#                    exterior_2nd_HdBoard  exterior_2nd_ImStucc  \
# ms_zoning_C (all)             -0.038111             -0.007111
# ms_zoning_FV                  -0.089699             -0.016737
# ms_zoning_I (all)             -0.008705             -0.001624
# ms_zoning_RH                  -0.015293             -0.006097
# ms_zoning_RL                   0.122891              0.022930
# ...                                 ...                   ...
# sale_type_ConLw                0.009536             -0.003635
# sale_type_New                 -0.114649             -0.021392
# sale_type_Oth                 -0.017422             -0.003251
# sale_type_WD                   0.047149              0.028575
# saleprice                     -0.102634              0.042654
#
#                    exterior_2nd_MetalSd  exterior_2nd_Plywood  \
# ms_zoning_C (all)              0.055744             -0.012458
# ms_zoning_FV                   0.111362             -0.071345
# ms_zoning_I (all)             -0.009582             -0.006924
# ms_zoning_RH                   0.061466             -0.025988
# ms_zoning_RL                  -0.179687              0.149942
# ...                                 ...                   ...
# sale_type_ConLw                0.005666             -0.015497
# sale_type_New                 -0.076344             -0.091190
# sale_type_Oth                  0.041433              0.024913
# sale_type_WD                   0.037856              0.060997
# saleprice                     -0.139558             -0.061517
#
#                    exterior_2nd_Stone  exterior_2nd_Stucco  \
# ms_zoning_C (all)           -0.005245            -0.011799
# ms_zoning_FV                -0.012346            -0.027770
# ms_zoning_I (all)           -0.001198            -0.002695
# ms_zoning_RH                -0.004497             0.039210
# ms_zoning_RL                 0.028806            -0.052898
# ...                               ...                  ...
# sale_type_ConLw             -0.002682            -0.006032
# sale_type_New               -0.015780            -0.020350
# sale_type_Oth               -0.002398            -0.005394
# sale_type_WD                 0.021078             0.023348
# saleprice                   -0.024674            -0.051952
#
#                    exterior_2nd_VinylSd  exterior_2nd_Wd Sdng  \
# ms_zoning_C (all)             -0.060666              0.054426
# ms_zoning_FV                   0.087079             -0.087234
# ms_zoning_I (all)             -0.016292              0.057707
# ms_zoning_RH                  -0.023931              0.003708
# ms_zoning_RL                   0.110464             -0.082210
# ...                                 ...                   ...
# sale_type_ConLw                0.004967              0.010674
# sale_type_New                  0.246366             -0.111498
# sale_type_Oth                 -0.009452             -0.016943
# sale_type_WD                  -0.134076              0.053722
# saleprice                      0.337851             -0.173208
#
#                    exterior_2nd_Wd Shng  mas_vnr_type_BrkFace  \
# ms_zoning_C (all)              0.012256             -0.064501
# ms_zoning_FV                  -0.027516             -0.029656
# ms_zoning_I (all)             -0.003938             -0.014732
# ms_zoning_RH                  -0.014780             -0.055299
# ms_zoning_RL                  -0.007687              0.162728
# ...                                 ...                   ...
# sale_type_ConLw               -0.008813             -0.032975
# sale_type_New                 -0.020251             -0.004805
# sale_type_Oth                 -0.007881             -0.029486
# sale_type_WD                   0.035788              0.021140
# saleprice                     -0.061250              0.258084
#
#                    mas_vnr_type_None  mas_vnr_type_Stone  exter_qual_Fa  \
# ms_zoning_C (all)           0.078354           -0.028928       0.216487
# ms_zoning_FV                0.004591            0.046963      -0.025827
# ms_zoning_I (all)           0.017896           -0.006607       0.194915
# ms_zoning_RH                0.067176           -0.024801       0.096455
# ms_zoning_RL               -0.177312            0.030041      -0.129185
# ...                              ...                 ...            ...
# sale_type_ConLw             0.040057           -0.014789      -0.005610
# sale_type_New              -0.132593            0.251124      -0.033011
# sale_type_Oth               0.035819           -0.013224      -0.005016
# sale_type_WD                0.081216           -0.184024      -0.020465
# saleprice                  -0.411571            0.310258      -0.131220
#
#                    exter_qual_Gd  exter_qual_TA  exter_cond_Fa  exter_cond_Gd  \
# ms_zoning_C (all)      -0.058757       0.015217       0.184817       0.000089
# ms_zoning_FV            0.259983      -0.250983      -0.035659      -0.070647
# ms_zoning_I (all)      -0.015876      -0.027493       0.141172      -0.007570
# ms_zoning_RH           -0.009563      -0.006115       0.025789      -0.009081
# ms_zoning_RL            0.048468      -0.038735      -0.109563      -0.037110
# ...                          ...            ...            ...            ...
# sale_type_ConLw        -0.014652       0.019510      -0.007745      -0.016943
# sale_type_New           0.224817      -0.332303      -0.045578      -0.099700
# sale_type_Oth          -0.031774       0.035564      -0.006926       0.020929
# sale_type_WD           -0.114257       0.205431      -0.005335       0.071869
# saleprice               0.447106      -0.601014      -0.156064      -0.059918
#
#                    exter_cond_Po  exter_cond_TA  foundation_CBlock  \
# ms_zoning_C (all)      -0.003026      -0.081923           0.030878
# ms_zoning_FV           -0.007121       0.082688          -0.189801
# ms_zoning_I (all)      -0.000691      -0.056358           0.025900
# ms_zoning_RH           -0.002594      -0.002333          -0.010794
# ms_zoning_RL           -0.021109       0.089721           0.133741
# ...                          ...            ...                ...
# sale_type_ConLw        -0.001547       0.019401          -0.022180
# sale_type_New          -0.009102       0.108814          -0.241061
# sale_type_Oth          -0.001383      -0.015188           0.007043
# sale_type_WD            0.012158      -0.063189           0.121062
# saleprice              -0.053938       0.122205          -0.356187
#
#                    foundation_PConc  foundation_Slab  foundation_Stone  \
# ms_zoning_C (all)         -0.077591         0.028066          0.201619
# ms_zoning_FV               0.246424        -0.029147         -0.011268
# ms_zoning_I (all)         -0.020060        -0.002829         -0.001093
# ms_zoning_RH               0.008059        -0.010617         -0.004104
# ms_zoning_RL               0.058479         0.030574         -0.069216
# ...                             ...              ...               ...
# sale_type_ConLw           -0.005135        -0.006331         -0.002447
# sale_type_New              0.313446        -0.037254         -0.014402
# sale_type_Oth             -0.017926        -0.005661         -0.002188
# sale_type_WD              -0.161222         0.026802          0.019237
# saleprice                  0.530973        -0.125993         -0.023883
#
#                    foundation_Wood  bsmt_height_Fa  bsmt_height_Gd  \
# ms_zoning_C (all)        -0.003026        0.043592       -0.082581
# ms_zoning_FV             -0.007121       -0.039568        0.193819
# ms_zoning_I (all)        -0.000691       -0.003840       -0.018862
# ms_zoning_RH             -0.002594       -0.014413       -0.010794
# ms_zoning_RL             -0.021109       -0.103321        0.107492
# ...                            ...             ...             ...
# sale_type_ConLw          -0.001547        0.050077       -0.022180
# sale_type_New            -0.009102       -0.050574        0.094248
# sale_type_Oth            -0.001383        0.123476       -0.015354
# sale_type_WD              0.012158        0.007551       -0.013604
# saleprice                -0.003052       -0.161673        0.227412
#
#                    bsmt_height_No basement  bsmt_height_Po  bsmt_height_TA  \
# ms_zoning_C (all)                 0.016305        0.228405        0.069596
# ms_zoning_FV                     -0.037123       -0.005034       -0.194527
# ms_zoning_I (all)                 0.135605       -0.000489       -0.019319
# ms_zoning_RH                     -0.013522       -0.001834        0.035119
# ms_zoning_RL                      0.004983       -0.041592       -0.106224
# ...                                    ...             ...             ...
# sale_type_ConLw                  -0.008063       -0.001093        0.016663
# sale_type_New                    -0.047449       -0.006434       -0.254451
# sale_type_Oth                    -0.007210       -0.000978       -0.016347
# sale_type_WD                      0.017858        0.008595        0.138590
# saleprice                        -0.160447       -0.025800       -0.457787
#
#                    bsmt_cond_Fa  bsmt_cond_Gd  bsmt_cond_No basement  \
# ms_zoning_C (all)      0.098693     -0.020626               0.016305
# ms_zoning_FV          -0.041236     -0.004304              -0.037123
# ms_zoning_I (all)     -0.004002     -0.004711               0.135605
# ms_zoning_RH           0.052588     -0.017683              -0.013522
# ms_zoning_RL          -0.132321      0.038138               0.004983
# ...                         ...           ...                    ...
# sale_type_ConLw        0.047484     -0.010545              -0.008063
# sale_type_New         -0.052705      0.098582              -0.047449
# sale_type_Oth         -0.008009     -0.009429              -0.007210
# sale_type_WD           0.004433     -0.058919               0.017858
# saleprice             -0.143632      0.114296              -0.160447
#
#                    bsmt_cond_Po  bsmt_cond_TA  bsmt_exposure_Gd  \
# ms_zoning_C (all)     -0.004787     -0.049936         -0.032099
# ms_zoning_FV           0.034427      0.041220         -0.075549
# ms_zoning_I (all)     -0.001093     -0.064536         -0.007331
# ms_zoning_RH          -0.004104     -0.010252         -0.027519
# ms_zoning_RL          -0.069216      0.056330          0.101353
# ...                         ...           ...               ...
# sale_type_ConLw       -0.002447     -0.015335         -0.016410
# sale_type_New          0.022466     -0.013077          0.080009
# sale_type_Oth         -0.002188      0.015151          0.022336
# sale_type_WD          -0.010055      0.027165         -0.040327
# saleprice             -0.035854      0.094185          0.377325
#
#                    bsmt_exposure_Mn  bsmt_exposure_No basement  \
# ms_zoning_C (all)          0.009179                   0.015005
# ms_zoning_FV               0.008010                  -0.024360
# ms_zoning_I (all)         -0.006499                   0.131823
# ms_zoning_RH              -0.002502                  -0.013910
# ms_zoning_RL               0.012604                   0.002399
# ...                             ...                        ...
# sale_type_ConLw            0.022009                  -0.008295
# sale_type_New             -0.025104                  -0.037653
# sale_type_Oth             -0.013009                  -0.007417
# sale_type_WD               0.023552                   0.012015
# saleprice                  0.029296                  -0.153122
#
#                    bsmt_exposure_No exposure  bsmtfin_type_1_BLQ  \
# ms_zoning_C (all)                   0.016983           -0.014677
# ms_zoning_FV                        0.033238           -0.052138
# ms_zoning_I (all)                  -0.030342           -0.007271
# ms_zoning_RH                        0.023080            0.032596
# ms_zoning_RL                       -0.137047            0.035895
# ...                                      ...                 ...
# sale_type_ConLw                    -0.005543            0.017056
# sale_type_New                      -0.116723           -0.089639
# sale_type_Oth                       0.008987           -0.014553
# sale_type_WD                        0.063006            0.045140
# saleprice                          -0.293522           -0.130285
#
#                    bsmtfin_type_1_GLQ  bsmtfin_type_1_LwQ  \
# ms_zoning_C (all)           -0.052283           -0.022155
# ms_zoning_FV                 0.160724           -0.052144
# ms_zoning_I (all)           -0.014480           -0.005060
# ms_zoning_RH                 0.010289            0.008247
# ms_zoning_RL                 0.049952           -0.008331
# ...
# ms_zoning_C (all)         -0.095069         0.087207        -0.067448
# ms_zoning_FV               0.071131        -0.034906         0.199914
# ms_zoning_I (all)         -0.070772        -0.003387        -0.017787
# ms_zoning_RH              -0.057393         0.026860        -0.018235
# ms_zoning_RL               0.148746        -0.060197         0.063382
# ...                             ...              ...              ...
# sale_type_ConLw            0.015450        -0.007582        -0.019555
# sale_type_New              0.090916        -0.044615         0.141960
# sale_type_Oth              0.013816        -0.006780        -0.035600
# sale_type_WD              -0.055400         0.040288        -0.051098
# saleprice                  0.252748        -0.155038         0.306959
#
#                    kitchen_qual_TA  functional_Maj2  functional_Min1  \
# ms_zoning_C (all)         0.053958        -0.005667        -0.014002
# ms_zoning_FV             -0.201129        -0.013338        -0.032956
# ms_zoning_I (all)         0.021633        -0.001294         0.152750
# ms_zoning_RH              0.021927        -0.004859        -0.012005
# ms_zoning_RL             -0.072259        -0.049635         0.018698
# ...                            ...              ...              ...
# sale_type_ConLw           0.028626        -0.002897        -0.007158
# sale_type_New            -0.275596        -0.017049        -0.042123
# sale_type_Oth             0.043297        -0.002591        -0.006401
# sale_type_WD              0.139933         0.022773         0.005269
# saleprice                -0.540651        -0.069723        -0.049410
#
#                    functional_Min2  functional_Mod  functional_Sal  \
# ms_zoning_C (all)         0.021933        0.031509       -0.003026
# ms_zoning_FV             -0.017045       -0.027297       -0.007121
# ms_zoning_I (all)        -0.003198       -0.002649       -0.000691
# ms_zoning_RH             -0.012005       -0.009943       -0.002594
# ms_zoning_RL             -0.006243       -0.006121       -0.058834
# ...                            ...             ...             ...
# sale_type_ConLw          -0.007158       -0.005929       -0.001547
# sale_type_New            -0.042123       -0.034889       -0.009102
# sale_type_Oth            -0.006401       -0.005302       -0.001383
# sale_type_WD              0.046067        0.022134       -0.034123
# saleprice                -0.056724       -0.050486       -0.059167
#
#                    functional_Sev  functional_Typ  fireplace_qu_Fa  \
# ms_zoning_C (all)       -0.003026       -0.015102        -0.016666
# ms_zoning_FV            -0.007121        0.051687        -0.025745
# ms_zoning_I (all)       -0.000691       -0.082873        -0.003807
# ms_zoning_RH            -0.002594        0.022127         0.021139
# ms_zoning_RL            -0.021109        0.028634         0.070393
# ...                           ...             ...              ...
# sale_type_ConLw         -0.001547        0.013194        -0.008520
# sale_type_New           -0.009102        0.077640        -0.050138
# sale_type_Oth           -0.001383        0.011798        -0.007619
# sale_type_WD             0.012158       -0.051457         0.066973
# saleprice               -0.033832        0.117838        -0.024340
#
#                    fireplace_qu_Gd  fireplace_qu_No Fireplace  \
# ms_zoning_C (all)        -0.056597                   0.099258
# ms_zoning_FV              0.006504                   0.039622
# ms_zoning_I (all)        -0.012927                   0.022671
# ms_zoning_RH             -0.048523                   0.061386
# ms_zoning_RL              0.067466                  -0.229197
# ...                            ...                        ...
# sale_type_ConLw          -0.006230                   0.011154
# sale_type_New             0.238888                  -0.083608
# sale_type_Oth            -0.025873                   0.045375
# sale_type_WD             -0.154033                   0.014706
# saleprice                 0.383834                  -0.485177
#
#                    fireplace_qu_Po  fireplace_qu_TA  garage_type_Attchd  \
# ms_zoning_C (all)        -0.011997        -0.048192           -0.116516
# ms_zoning_FV             -0.028236        -0.039963            0.037753
# ms_zoning_I (all)        -0.002740        -0.011007           -0.026613
# ms_zoning_RH             -0.010285        -0.026467           -0.039609
# ms_zoning_RL              0.027279         0.164258            0.294638
# ...                            ...              ...                 ...
# sale_type_ConLw          -0.006133         0.000157           -0.039435
# sale_type_New            -0.036090        -0.135859            0.134422
# sale_type_Oth            -0.005484        -0.022031           -0.030763
# sale_type_WD              0.036368         0.121205           -0.072959
# saleprice                -0.066064         0.147145            0.356984
#
#                    garage_type_Basment  garage_type_BuiltIn  \
# ms_zoning_C (all)             0.033468            -0.025399
# ms_zoning_FV                 -0.026325            -0.032231
# ms_zoning_I (all)            -0.002555            -0.005801
# ms_zoning_RH                 -0.009589            -0.021776
# ms_zoning_RL                  0.009771             0.091499
# ...                                ...                  ...
# sale_type_ConLw              -0.005718            -0.012985
# sale_type_New                -0.017696             0.086598
# sale_type_Oth                -0.005113            -0.011611
# sale_type_WD                 -0.018423            -0.045105
# saleprice                    -0.055790             0.219972
#
#                    garage_type_CarPort  garage_type_Detchd  \
# ms_zoning_C (all)             0.062571            0.046935
# ms_zoning_FV                 -0.016737            0.018825
# ms_zoning_I (all)            -0.001624            0.037216
# ms_zoning_RH                  0.074981            0.004719
# ms_zoning_RL                 -0.009312           -0.328515
# ...                                ...                 ...
# sale_type_ConLw              -0.003635            0.060764
# sale_type_New                -0.021392           -0.156312
# sale_type_Oth                -0.003251            0.024107
# sale_type_WD                  0.008798            0.082774
# saleprice                    -0.072030           -0.369449
#
#                    garage_type_No Garage  garage_finish_No Garage  \
# ms_zoning_C (all)               0.155068                 0.155068
# ms_zoning_FV                   -0.055040                -0.055040
# ms_zoning_I (all)              -0.005341                -0.005341
# ms_zoning_RH                    0.057814                 0.057814
# ms_zoning_RL                   -0.108972                -0.108972
# ...                                  ...                      ...
# sale_type_ConLw                -0.011955                -0.011955
# sale_type_New                  -0.054412                -0.054412
# sale_type_Oth                   0.037747                 0.037747
# sale_type_WD                    0.049651                 0.049651
# saleprice                      -0.231243                -0.231243
#
#                    garage_finish_RFn  garage_finish_Unf  garage_qual_Fa  \
# ms_zoning_C (all)          -0.026823           0.001469        0.006216
# ms_zoning_FV                0.082355          -0.090532       -0.046515
# ms_zoning_I (all)          -0.013876           0.026319       -0.004514
# ms_zoning_RH               -0.052086           0.014560       -0.016944
# ms_zoning_RL                0.163550          -0.185376       -0.155919
# ...                              ...                ...             ...
# sale_type_ConLw            -0.009087           0.038818        0.040364
# sale_type_New               0.035416          -0.211222       -0.059453
# sale_type_Oth              -0.027773           0.030220       -0.009035
# sale_type_WD               -0.035149           0.124021        0.035175
# saleprice                   0.184690          -0.433129       -0.168321
#
#                    garage_qual_Gd  garage_qual_No Garage  garage_qual_Po  \
# ms_zoning_C (all)       -0.009112               0.155068       -0.003026
# ms_zoning_FV             0.002713              -0.055040       -0.007121
# ms_zoning_I (all)       -0.002081              -0.005341       -0.000691
# ms_zoning_RH            -0.007812               0.057814       -0.002594
# ms_zoning_RL             0.012168              -0.108972       -0.021109
# ...                           ...                    ...             ...
# sale_type_ConLw         -0.004658              -0.011955       -0.001547
# sale_type_New           -0.007919              -0.054412       -0.009102
# sale_type_Oth           -0.004166               0.037747       -0.001383
# sale_type_WD             0.021129               0.049651        0.012158
# saleprice                0.096869              -0.231243       -0.045967
#
#                    garage_qual_TA  paved_drive_P  paved_drive_Y  pool_qc_Fa  \
# ms_zoning_C (all)       -0.115229      -0.013483      -0.197276   -0.003026
# ms_zoning_FV             0.071299      -0.031734       0.072834   -0.007121
# ms_zoning_I (all)        0.007629      -0.003080      -0.069117   -0.000691
# ms_zoning_RH            -0.029010      -0.011559      -0.055175   -0.002594
# ms_zoning_RL             0.183364      -0.029412       0.215908    0.016615
# ...                           ...            ...            ...         ...
# sale_type_ConLw         -0.015007      -0.006893      -0.018285   -0.001547
# sale_type_New            0.082777      -0.040560       0.093092   -0.009102
# sale_type_Oth           -0.020591      -0.006164      -0.062095   -0.001383
# sale_type_WD            -0.068591       0.033026      -0.049608    0.012158
# saleprice                0.249967      -0.090847       0.289538    0.013423
#
#                    pool_qc_Gd  pool_qc_No Pool  pool_qc_TA  fence_GdWo  \
# ms_zoning_C (all)   -0.004281         0.006429   -0.003026    0.006777
# ms_zoning_FV        -0.010076         0.015132   -0.007121   -0.034282
# ms_zoning_I (all)   -0.000978         0.001468   -0.000691   -0.004456
# ms_zoning_RH        -0.003670         0.005512   -0.002594   -0.016727
# ms_zoning_RL         0.023509        -0.035306    0.016615    0.040244
# ...                       ...              ...         ...         ...
# sale_type_ConLw     -0.002188         0.003287   -0.001547   -0.009974
# sale_type_New        0.028332        -0.008166   -0.009102   -0.058694
# sale_type_Oth       -0.001957         0.002939   -0.001383   -0.008919
# sale_type_WD        -0.015539        -0.003980    0.012158    0.048556
# saleprice            0.019547        -0.024375   -0.015778   -0.101752
#
#                    fence_MnPrv  fence_MnWw  fence_No fence  misc_feature_Gar2  \
# ms_zoning_C (all)    -0.001423   -0.006779        0.008912          -0.004281
# ms_zoning_FV         -0.080016   -0.015954        0.106162          -0.010076
# ms_zoning_I (all)    -0.007765   -0.001548        0.010855          -0.000978
# ms_zoning_RH          0.008753   -0.005811        0.010794          -0.003670
# ms_zoning_RL          0.002066    0.003417       -0.034679          -0.003180
# ...                        ...         ...             ...                ...
# sale_type_ConLw      -0.017380   -0.003465        0.024297          -0.002188
# sale_type_New        -0.102272   -0.020392        0.142974          -0.012878
# sale_type_Oth         0.055189   -0.003099       -0.034173          -0.001957
# sale_type_WD          0.062650    0.006501       -0.099648           0.017202
# saleprice            -0.148613   -0.040952        0.180310          -0.019533
#
#                    misc_feature_No extra features  misc_feature_Othr  \
# ms_zoning_C (all)                       -0.011533          -0.003706
# ms_zoning_FV                             0.041236          -0.008724
# ms_zoning_I (all)                        0.004002          -0.000847
# ms_zoning_RH                             0.015020          -0.003178
# ms_zoning_RL                            -0.042440          -0.010455
# ...                                           ...                ...
# sale_type_ConLw                          0.008957          -0.001895
# sale_type_New                            0.042326          -0.011150
# sale_type_Oth                            0.008009          -0.001694
# sale_type_WD                            -0.037417           0.014894
# saleprice                                0.048541          -0.008855
#
#                    misc_feature_Shed  misc_feature_TenC  sale_type_CWD  \
# ms_zoning_C (all)           0.015005          -0.002139      -0.006779
# ms_zoning_FV               -0.038188          -0.005034       0.016397
# ms_zoning_I (all)          -0.003706          -0.000489      -0.001548
# ms_zoning_RH               -0.013910          -0.001834      -0.005811
# ms_zoning_RL                0.045750           0.011746       0.003417
# ...                              ...                ...            ...
# sale_type_ConLw            -0.008295          -0.001093      -0.003465
# sale_type_New              -0.048810          -0.006434      -0.020392
# sale_type_Oth              -0.007417          -0.000978      -0.003099
# sale_type_WD                0.038607           0.008595      -0.180140
# saleprice                  -0.047491           0.019114       0.004554
#
#                    sale_type_Con  sale_type_ConLD  sale_type_ConLI  \
# ms_zoning_C (all)      -0.004281         0.107110        -0.005667
# ms_zoning_FV            0.041000         0.031016        -0.013338
# ms_zoning_I (all)      -0.000978         0.249082        -0.001294
# ms_zoning_RH           -0.003670        -0.007362        -0.004859
# ms_zoning_RL           -0.003180        -0.019761        -0.009257
# ...                          ...              ...              ...
# sale_type_ConLw        -0.002188        -0.004390        -0.002897
# sale_type_New          -0.012878        -0.025832        -0.017049
# sale_type_Oth          -0.001957        -0.003925        -0.002591
# sale_type_WD           -0.113763        -0.228197        -0.150605
# saleprice               0.033681        -0.055173         0.019594
#
#                    sale_type_ConLw  sale_type_New  sale_type_Oth  \
# ms_zoning_C (all)        -0.004787      -0.028171      -0.004281
# ms_zoning_FV             -0.011268       0.194184      -0.010076
# ms_zoning_I (all)        -0.001093      -0.006434      -0.000978
# ms_zoning_RH             -0.004104      -0.024152      -0.003670
# ms_zoning_RL             -0.021463      -0.003362      -0.003180
# ...                            ...            ...            ...
# sale_type_ConLw           1.000000      -0.014402      -0.002188
# sale_type_New            -0.014402       1.000000      -0.012878
# sale_type_Oth            -0.002188      -0.012878       1.000000
# sale_type_WD             -0.127222      -0.748636      -0.113763
# saleprice                -0.035519       0.358378      -0.030143
#
#                    sale_type_WD   saleprice
# ms_zoning_C (all)      -0.022683  -0.126380
# ms_zoning_FV           -0.145097   0.106749
# ms_zoning_I (all)      -0.056840  -0.034553
# ms_zoning_RH            0.014717  -0.034162
# ms_zoning_RL            0.013124   0.230202
# ...                          ...        ...
# sale_type_ConLw        -0.127222  -0.035519
# sale_type_New          -0.748636   0.358378
# sale_type_Oth          -0.113763  -0.030143
# sale_type_WD            1.000000  -0.214881
# saleprice              -0.214881   1.000000
#
# [221 rows x 221 columns]

# %% [markdown]
# The four categorical column with the highest correlation coeffiecient to the sale price are : foundation, bsmtfin_type, neighborhood, exter_qual, fireplace_qu
#
#
# 1. foundation : 0.530973
# 2. bsmtfin_type_1 : 0.463972
# 3. neighborhood : 0.449007
# 4. exter_qual : 0.447106

# %% [markdown]
# I am going to add this features to the numerical values to fit our models. I will first perform a linear regression model with only numerical features and then add those categorical features to see how my initial model improve.

# %% [markdown]
# Let's explore the relationship between foundation and sale price:

# %%
plt.figure(figsize=(12, 8))
sns.barplot(data=house_train_set, x=house_test_data['foundation'], y=house_train_set['saleprice'])
plt.title('Sale price per foundation', fontsize=20);

# %% [markdown]
# Here we can see that most foundation average at about the same price. The wood foundation are cheaper in general and the foundation that yield that highest sale price is the slab foundation
